# %% [markdown]
# <a href="https://colab.research.google.com/github/imranhossian607/thesis2.0/blob/main/dropout_0_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import warnings

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow import keras
import tensorflow
import scipy
print("Num GPUs Available: ", len(tensorflow.config.list_physical_devices('GPU')))


# Set the seed value for experiment reproduci.bility.
seed = 1842
tensorflow.random.set_seed(seed)
np.random.seed(seed)
# Turn off warnings for cleaner looking notebook
warnings.simplefilter('ignore')
# Out:
# Num GPUs Available:  1

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Split the dataset into train, validation, and test sets
input_folder = '/content/drive/MyDrive/Dataset'
output_folder = 'output'

splitfolders.ratio(input_folder, output=output_folder, seed=1345, ratio=(0.7, 0.15, 0.15))

# Define data augmentation parameters
WIDTH,HEIGHT=224,224

train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.2,          # Zoom in/out by a maximum of 20%
                                   horizontal_flip=True,)

valid_datagen = ImageDataGenerator(rescale = 1./255)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# Define the directories for your training, validation, and test sets
train_dir = os.path.join(output_folder, 'train')
valid_dir = os.path.join(output_folder, 'val')
test_dir = os.path.join(output_folder, 'test')

# Apply data augmentation to the training dataset
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size = (WIDTH,HEIGHT),
    color_mode = "rgb",
    batch_size = 64,
    interpolation = "bicubic" ,
    shuffle = True ,
    class_mode='categorical'  # Change to appropriate mode for your dataset
)


# No augmentation for validation and test datasets
valid_data = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=(WIDTH,HEIGHT),   # Adjust the target size as needed
    color_mode = "rgb",
    batch_size = 64,
    interpolation = "bicubic" ,
    shuffle = True ,
    class_mode='categorical'  # Change to appropriate mode for your dataset
)

test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=(WIDTH,HEIGHT),   # Adjust the target size as needed
    color_mode = "rgb",
    batch_size = 64,
    interpolation = "bicubic" ,
    shuffle = True ,
    class_mode='categorical'  # Change to appropriate mode for your dataset
)
# Out:
# Copying files: 6400 files [02:01, 52.62 files/s]
# Found 4479 images belonging to 4 classes.
# Found 959 images belonging to 4 classes.
# Found 962 images belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

batch_1_img = train_data[0]
plt.figure(figsize=(12, 4))  # Adjust the figure size as needed

for i in range(4):
    img = batch_1_img[0][i]
    lab = batch_1_img[1][i]

    # Create a subplot for each image
    plt.subplot(1, 4, i + 1)
    plt.imshow(img)
    plt.title(f'Class: {lab}')  # Set the title to display the class label
    plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt

batch_1_img = test_data[0]
plt.figure(figsize=(12, 4))  # Adjust the figure size as needed

for i in range(4):
    img = batch_1_img[0][i]
    lab = batch_1_img[1][i]

    # Create a subplot for each image
    plt.subplot(1, 4, i + 1)
    plt.imshow(img)
    plt.title(f'Class: {lab}')  # Set the title to display the class label
    plt.axis('off')

plt.show()

# %% [markdown]
# #CNN

# %%
import tensorflow as tf
from tensorflow import keras

input_shape = (WIDTH, HEIGHT, 3)

# Define your CNN model
model = keras.models.Sequential()

model.add(keras.layers.Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu', kernel_initializer="he_normal", input_shape=input_shape))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(keras.layers.Dropout(0.40))

model.add(keras.layers.Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu', kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(keras.layers.Dropout(0.40))

model.add(keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu', kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(keras.layers.Dropout(0.40))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128, activation="relu", kernel_initializer="he_normal"))
model.add(keras.layers.Dense(64, activation="relu"))
model.add(keras.layers.Dense(4, activation="softmax"))

# Print model summary
model.summary()

# Compile the model
model.compile(
    optimizer='adam',
    loss=tf.losses.CategoricalCrossentropy(),
    metrics=["accuracy", tf.metrics.Recall(), tf.metrics.Precision(), tf.metrics.AUC()]
)

# Early stopping callback
callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# Train the model
model_history = model.fit(train_data, epochs=100, validation_data=valid_data, callbacks=[callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 16)      0
#  D)
#
#  dropout (Dropout)           (None, 112, 112, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 56, 56, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 28, 28, 64)        0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 128)               6422656
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 6454756 (24.62 MB)
# Trainable params: 6454756 (24.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 70/70 [==============================] - 93s 952ms/step - loss: 2.7754 - accuracy: 0.4351 - recall: 0.2565 - precision: 0.4547 - auc: 0.7181 - val_loss: 1.3113 - val_accuracy: 0.5005 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.7817
# Epoch 2/100
# 70/70 [==============================] - 73s 1s/step - loss: 1.0280 - accuracy: 0.5006 - recall: 0.2478 - precision: 0.5522 - auc: 0.7905 - val_loss: 1.2946 - val_accuracy: 0.5068 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.7947
# Epoch 3/100
# 70/70 [==============================] - 66s 950ms/step - loss: 1.0217 - accuracy: 0.4981 - recall: 0.2914 - precision: 0.5625 - auc: 0.7957 - val_loss: 1.3040 - val_accuracy: 0.5120 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.8113
# Epoch 4/100
# 70/70 [==============================] - 67s 960ms/step - loss: 0.9965 - accuracy: 0.5090 - recall: 0.3302 - precision: 0.6071 - auc: 0.8075 - val_loss: 1.2762 - val_accuracy: 0.5224 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.8082
# Epoch 5/100
# 70/70 [==============================] - 66s 937ms/step - loss: 0.9772 - accuracy: 0.5189 - recall: 0.3242 - precision: 0.6391 - auc: 0.8140 - val_loss: 1.2458 - val_accuracy: 0.5141 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.8173
# Epoch 6/100
# 70/70 [==============================] - 66s 945ms/step - loss: 0.9653 - accuracy: 0.5267 - recall: 0.3327 - precision: 0.6414 - auc: 0.8191 - val_loss: 1.1981 - val_accuracy: 0.5349 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.8228
# Epoch 7/100
# 70/70 [==============================] - 68s 961ms/step - loss: 0.9526 - accuracy: 0.5320 - recall: 0.3496 - precision: 0.6384 - auc: 0.8233 - val_loss: 1.1753 - val_accuracy: 0.5360 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.8254
# Epoch 8/100
# 70/70 [==============================] - 66s 943ms/step - loss: 0.9382 - accuracy: 0.5443 - recall: 0.3427 - precision: 0.6515 - auc: 0.8286 - val_loss: 1.1574 - val_accuracy: 0.5506 - val_recall: 0.0042 - val_precision: 1.0000 - val_auc: 0.8248
# Epoch 9/100
# 70/70 [==============================] - 71s 1s/step - loss: 0.9286 - accuracy: 0.5555 - recall: 0.3519 - precision: 0.6608 - auc: 0.8337 - val_loss: 1.1713 - val_accuracy: 0.5547 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.8169
# Epoch 10/100
# 70/70 [==============================] - 66s 942ms/step - loss: 0.9282 - accuracy: 0.5481 - recall: 0.3374 - precision: 0.6636 - auc: 0.8332 - val_loss: 1.1454 - val_accuracy: 0.5162 - val_recall: 0.0094 - val_precision: 1.0000 - val_auc: 0.8161
# Epoch 11/100
# 70/70 [==============================] - 69s 986ms/step - loss: 0.9159 - accuracy: 0.5655 - recall: 0.3499 - precision: 0.6795 - auc: 0.8384 - val_loss: 1.0725 - val_accuracy: 0.5589 - val_recall: 0.1491 - val_precision: 0.9167 - val_auc: 0.8336
# Epoch 12/100
# 70/70 [==============================] - 66s 942ms/step - loss: 0.9056 - accuracy: 0.5595 - recall: 0.3532 - precision: 0.6781 - auc: 0.8407 - val_loss: 1.0687 - val_accuracy: 0.5318 - val_recall: 0.1283 - val_precision: 0.9318 - val_auc: 0.8317
# Epoch 13/100
# 70/70 [==============================] - 70s 996ms/step - loss: 0.8999 - accuracy: 0.5579 - recall: 0.3494 - precision: 0.6840 - auc: 0.8421 - val_loss: 1.0006 - val_accuracy: 0.5798 - val_recall: 0.2231 - val_precision: 0.8075 - val_auc: 0.8444
# Epoch 14/100
# 70/70 [==============================] - 69s 983ms/step - loss: 0.8992 - accuracy: 0.5620 - recall: 0.3599 - precision: 0.6813 - auc: 0.8423 - val_loss: 1.0540 - val_accuracy: 0.5589 - val_recall: 0.1741 - val_precision: 0.8789 - val_auc: 0.8432
# Epoch 15/100
# 70/70 [==============================] - 69s 990ms/step - loss: 0.8909 - accuracy: 0.5695 - recall: 0.3666 - precision: 0.6813 - auc: 0.8461 - val_loss: 1.0491 - val_accuracy: 0.5589 - val_recall: 0.1324 - val_precision: 0.9338 - val_auc: 0.8365
# Epoch 16/100
# 70/70 [==============================] - 69s 988ms/step - loss: 0.8801 - accuracy: 0.5722 - recall: 0.3833 - precision: 0.6792 - auc: 0.8490 - val_loss: 1.0114 - val_accuracy: 0.5516 - val_recall: 0.1981 - val_precision: 0.8407 - val_auc: 0.8396
# Epoch 17/100
# 70/70 [==============================] - 66s 942ms/step - loss: 0.8768 - accuracy: 0.5740 - recall: 0.3941 - precision: 0.6775 - auc: 0.8506 - val_loss: 0.9912 - val_accuracy: 0.5600 - val_recall: 0.1940 - val_precision: 0.8571 - val_auc: 0.8482
# Epoch 18/100
# 70/70 [==============================] - 67s 962ms/step - loss: 0.8672 - accuracy: 0.5778 - recall: 0.3865 - precision: 0.6905 - auc: 0.8548 - val_loss: 0.9820 - val_accuracy: 0.5735 - val_recall: 0.2190 - val_precision: 0.8108 - val_auc: 0.8532
# Epoch 19/100
# 70/70 [==============================] - 66s 951ms/step - loss: 0.8703 - accuracy: 0.5798 - recall: 0.4023 - precision: 0.6782 - auc: 0.8527 - val_loss: 0.9987 - val_accuracy: 0.5850 - val_recall: 0.1616 - val_precision: 0.9281 - val_auc: 0.8579
# Epoch 20/100
# 70/70 [==============================] - 69s 987ms/step - loss: 0.8469 - accuracy: 0.6102 - recall: 0.4226 - precision: 0.6932 - auc: 0.8630 - val_loss: 0.9435 - val_accuracy: 0.5798 - val_recall: 0.2054 - val_precision: 0.8528 - val_auc: 0.8554
# Epoch 21/100
# 70/70 [==============================] - 66s 946ms/step - loss: 0.8452 - accuracy: 0.5850 - recall: 0.4336 - precision: 0.6669 - auc: 0.8610 - val_loss: 0.9550 - val_accuracy: 0.6048 - val_recall: 0.2450 - val_precision: 0.7939 - val_auc: 0.8608
# Epoch 22/100
# 70/70 [==============================] - 67s 957ms/step - loss: 0.8419 - accuracy: 0.5972 - recall: 0.4291 - precision: 0.6924 - auc: 0.8637 - val_loss: 0.9163 - val_accuracy: 0.6152 - val_recall: 0.2544 - val_precision: 0.8026 - val_auc: 0.8683
# Epoch 23/100
# 70/70 [==============================] - 68s 971ms/step - loss: 0.8388 - accuracy: 0.5992 - recall: 0.4394 - precision: 0.6996 - auc: 0.8650 - val_loss: 0.9242 - val_accuracy: 0.6090 - val_recall: 0.2450 - val_precision: 0.8608 - val_auc: 0.8639
# Epoch 24/100
# 70/70 [==============================] - 70s 1s/step - loss: 0.8322 - accuracy: 0.5930 - recall: 0.4568 - precision: 0.6710 - auc: 0.8662 - val_loss: 0.9088 - val_accuracy: 0.6069 - val_recall: 0.2836 - val_precision: 0.7662 - val_auc: 0.8682
# Epoch 25/100
# 70/70 [==============================] - 69s 984ms/step - loss: 0.8338 - accuracy: 0.6050 - recall: 0.4461 - precision: 0.6873 - auc: 0.8669 - val_loss: 0.8977 - val_accuracy: 0.6100 - val_recall: 0.2482 - val_precision: 0.8351 - val_auc: 0.8685
# Epoch 26/100
# 70/70 [==============================] - 66s 950ms/step - loss: 0.8171 - accuracy: 0.6117 - recall: 0.4630 - precision: 0.6895 - auc: 0.8721 - val_loss: 0.8909 - val_accuracy: 0.5985 - val_recall: 0.2377 - val_precision: 0.8352 - val_auc: 0.8722
# Epoch 27/100
# 70/70 [==============================] - 69s 992ms/step - loss: 0.8195 - accuracy: 0.6129 - recall: 0.4762 - precision: 0.6865 - auc: 0.8707 - val_loss: 0.8741 - val_accuracy: 0.5798 - val_recall: 0.2847 - val_precision: 0.8149 - val_auc: 0.8648
# Epoch 28/100
# 70/70 [==============================] - 66s 951ms/step - loss: 0.8006 - accuracy: 0.6169 - recall: 0.4883 - precision: 0.6908 - auc: 0.8762 - val_loss: 0.8513 - val_accuracy: 0.6090 - val_recall: 0.3180 - val_precision: 0.7761 - val_auc: 0.8772
# Epoch 29/100
# 70/70 [==============================] - 70s 1s/step - loss: 0.7964 - accuracy: 0.6267 - recall: 0.4896 - precision: 0.6931 - auc: 0.8793 - val_loss: 0.8254 - val_accuracy: 0.6413 - val_recall: 0.3347 - val_precision: 0.7906 - val_auc: 0.8863
# Epoch 30/100
# 70/70 [==============================] - 65s 929ms/step - loss: 0.7841 - accuracy: 0.6296 - recall: 0.5133 - precision: 0.6979 - auc: 0.8822 - val_loss: 0.8030 - val_accuracy: 0.6694 - val_recall: 0.3650 - val_precision: 0.7919 - val_auc: 0.8941
# Epoch 31/100
# 70/70 [==============================] - 68s 967ms/step - loss: 0.7693 - accuracy: 0.6350 - recall: 0.5227 - precision: 0.6957 - auc: 0.8868 - val_loss: 0.8354 - val_accuracy: 0.6413 - val_recall: 0.3347 - val_precision: 0.8252 - val_auc: 0.8895
# Epoch 32/100
# 70/70 [==============================] - 66s 933ms/step - loss: 0.7712 - accuracy: 0.6403 - recall: 0.5287 - precision: 0.6938 - auc: 0.8861 - val_loss: 0.7802 - val_accuracy: 0.6580 - val_recall: 0.4056 - val_precision: 0.7703 - val_auc: 0.8981
# Epoch 33/100
# 70/70 [==============================] - 64s 910ms/step - loss: 0.7661 - accuracy: 0.6461 - recall: 0.5416 - precision: 0.7058 - auc: 0.8885 - val_loss: 0.8068 - val_accuracy: 0.6684 - val_recall: 0.3545 - val_precision: 0.8458 - val_auc: 0.8998
# Epoch 34/100
# 70/70 [==============================] - 63s 893ms/step - loss: 0.7457 - accuracy: 0.6490 - recall: 0.5457 - precision: 0.7060 - auc: 0.8943 - val_loss: 0.7585 - val_accuracy: 0.6465 - val_recall: 0.4599 - val_precision: 0.7750 - val_auc: 0.8962
# Epoch 35/100
# 70/70 [==============================] - 62s 894ms/step - loss: 0.7380 - accuracy: 0.6562 - recall: 0.5666 - precision: 0.7097 - auc: 0.8962 - val_loss: 0.7474 - val_accuracy: 0.6736 - val_recall: 0.4640 - val_precision: 0.7726 - val_auc: 0.9060
# Epoch 36/100
# 70/70 [==============================] - 63s 896ms/step - loss: 0.7256 - accuracy: 0.6589 - recall: 0.5722 - precision: 0.7108 - auc: 0.8994 - val_loss: 0.7487 - val_accuracy: 0.6694 - val_recall: 0.4797 - val_precision: 0.8000 - val_auc: 0.9062
# Epoch 37/100
# 70/70 [==============================] - 63s 894ms/step - loss: 0.7235 - accuracy: 0.6644 - recall: 0.5747 - precision: 0.7255 - auc: 0.9010 - val_loss: 0.7217 - val_accuracy: 0.6830 - val_recall: 0.4818 - val_precision: 0.7611 - val_auc: 0.9090
# Epoch 38/100
# 70/70 [==============================] - 63s 894ms/step - loss: 0.7108 - accuracy: 0.6638 - recall: 0.5823 - precision: 0.7133 - auc: 0.9041 - val_loss: 0.7373 - val_accuracy: 0.6715 - val_recall: 0.4911 - val_precision: 0.7903 - val_auc: 0.9085
# Epoch 39/100
# 70/70 [==============================] - 64s 919ms/step - loss: 0.7047 - accuracy: 0.6725 - recall: 0.5894 - precision: 0.7201 - auc: 0.9061 - val_loss: 0.7133 - val_accuracy: 0.6799 - val_recall: 0.5297 - val_precision: 0.7482 - val_auc: 0.9069
# Epoch 40/100
# 70/70 [==============================] - 64s 912ms/step - loss: 0.6938 - accuracy: 0.6805 - recall: 0.6053 - precision: 0.7202 - auc: 0.9085 - val_loss: 0.6825 - val_accuracy: 0.6976 - val_recall: 0.5318 - val_precision: 0.8226 - val_auc: 0.9258
# Epoch 41/100
# 70/70 [==============================] - 63s 902ms/step - loss: 0.6802 - accuracy: 0.6912 - recall: 0.6158 - precision: 0.7331 - auc: 0.9129 - val_loss: 0.6931 - val_accuracy: 0.7039 - val_recall: 0.5172 - val_precision: 0.7949 - val_auc: 0.9193
# Epoch 42/100
# 70/70 [==============================] - 63s 896ms/step - loss: 0.6685 - accuracy: 0.6935 - recall: 0.6283 - precision: 0.7351 - auc: 0.9150 - val_loss: 0.6536 - val_accuracy: 0.7112 - val_recall: 0.5902 - val_precision: 0.7949 - val_auc: 0.9271
# Epoch 43/100
# 70/70 [==============================] - 65s 928ms/step - loss: 0.6597 - accuracy: 0.7004 - recall: 0.6383 - precision: 0.7355 - auc: 0.9173 - val_loss: 0.6782 - val_accuracy: 0.7059 - val_recall: 0.5725 - val_precision: 0.7922 - val_auc: 0.9211
# Epoch 44/100
# 70/70 [==============================] - 64s 922ms/step - loss: 0.6493 - accuracy: 0.7098 - recall: 0.6452 - precision: 0.7487 - auc: 0.9212 - val_loss: 0.6553 - val_accuracy: 0.6955 - val_recall: 0.6027 - val_precision: 0.7758 - val_auc: 0.9208
# Epoch 45/100
# 70/70 [==============================] - 64s 923ms/step - loss: 0.6383 - accuracy: 0.7127 - recall: 0.6546 - precision: 0.7535 - auc: 0.9241 - val_loss: 0.6253 - val_accuracy: 0.7372 - val_recall: 0.6455 - val_precision: 0.7946 - val_auc: 0.9361
# Epoch 46/100
# 70/70 [==============================] - 67s 961ms/step - loss: 0.6259 - accuracy: 0.7207 - recall: 0.6682 - precision: 0.7556 - auc: 0.9269 - val_loss: 0.6495 - val_accuracy: 0.6966 - val_recall: 0.6163 - val_precision: 0.7500 - val_auc: 0.9227
# Epoch 47/100
# 70/70 [==============================] - 64s 906ms/step - loss: 0.6108 - accuracy: 0.7245 - recall: 0.6752 - precision: 0.7627 - auc: 0.9305 - val_loss: 0.6217 - val_accuracy: 0.7414 - val_recall: 0.6079 - val_precision: 0.8270 - val_auc: 0.9398
# Epoch 48/100
# 70/70 [==============================] - 63s 905ms/step - loss: 0.6170 - accuracy: 0.7249 - recall: 0.6700 - precision: 0.7621 - auc: 0.9287 - val_loss: 0.5924 - val_accuracy: 0.7602 - val_recall: 0.6538 - val_precision: 0.8294 - val_auc: 0.9445
# Epoch 49/100
# 70/70 [==============================] - 64s 916ms/step - loss: 0.5943 - accuracy: 0.7401 - recall: 0.6939 - precision: 0.7776 - auc: 0.9347 - val_loss: 0.5567 - val_accuracy: 0.7779 - val_recall: 0.6694 - val_precision: 0.8305 - val_auc: 0.9482
# Epoch 50/100
# 70/70 [==============================] - 64s 910ms/step - loss: 0.5748 - accuracy: 0.7470 - recall: 0.7040 - precision: 0.7745 - auc: 0.9384 - val_loss: 0.5719 - val_accuracy: 0.7570 - val_recall: 0.6528 - val_precision: 0.8324 - val_auc: 0.9471
# Epoch 51/100
# 70/70 [==============================] - 65s 917ms/step - loss: 0.5892 - accuracy: 0.7334 - recall: 0.6897 - precision: 0.7738 - auc: 0.9352 - val_loss: 0.5576 - val_accuracy: 0.7696 - val_recall: 0.6663 - val_precision: 0.8364 - val_auc: 0.9505
# Epoch 52/100
# 70/70 [==============================] - 64s 912ms/step - loss: 0.5484 - accuracy: 0.7624 - recall: 0.7207 - precision: 0.7929 - auc: 0.9442 - val_loss: 0.5490 - val_accuracy: 0.7904 - val_recall: 0.7164 - val_precision: 0.8399 - val_auc: 0.9523
# Epoch 53/100
# 70/70 [==============================] - 66s 935ms/step - loss: 0.5458 - accuracy: 0.7598 - recall: 0.7247 - precision: 0.7884 - auc: 0.9450 - val_loss: 0.5093 - val_accuracy: 0.8081 - val_recall: 0.7299 - val_precision: 0.8631 - val_auc: 0.9608
# Epoch 54/100
# 70/70 [==============================] - 67s 961ms/step - loss: 0.5332 - accuracy: 0.7611 - recall: 0.7256 - precision: 0.7933 - auc: 0.9473 - val_loss: 0.5501 - val_accuracy: 0.7560 - val_recall: 0.7070 - val_precision: 0.7976 - val_auc: 0.9449
# Epoch 55/100
# 70/70 [==============================] - 64s 921ms/step - loss: 0.5410 - accuracy: 0.7587 - recall: 0.7256 - precision: 0.7829 - auc: 0.9455 - val_loss: 0.4974 - val_accuracy: 0.8196 - val_recall: 0.7310 - val_precision: 0.8840 - val_auc: 0.9651
# Epoch 56/100
# 70/70 [==============================] - 64s 914ms/step - loss: 0.5167 - accuracy: 0.7765 - recall: 0.7412 - precision: 0.8029 - auc: 0.9507 - val_loss: 0.5026 - val_accuracy: 0.7706 - val_recall: 0.7289 - val_precision: 0.8016 - val_auc: 0.9521
# Epoch 57/100
# 70/70 [==============================] - 64s 916ms/step - loss: 0.5173 - accuracy: 0.7729 - recall: 0.7403 - precision: 0.7979 - auc: 0.9504 - val_loss: 0.4537 - val_accuracy: 0.8488 - val_recall: 0.7852 - val_precision: 0.8848 - val_auc: 0.9711
# Epoch 58/100
# 70/70 [==============================] - 64s 912ms/step - loss: 0.4893 - accuracy: 0.7937 - recall: 0.7665 - precision: 0.8187 - auc: 0.9557 - val_loss: 0.4612 - val_accuracy: 0.8165 - val_recall: 0.7737 - val_precision: 0.8750 - val_auc: 0.9703
# Epoch 59/100
# 70/70 [==============================] - 64s 913ms/step - loss: 0.4997 - accuracy: 0.7794 - recall: 0.7464 - precision: 0.8024 - auc: 0.9535 - val_loss: 0.4479 - val_accuracy: 0.8175 - val_recall: 0.7539 - val_precision: 0.8566 - val_auc: 0.9673
# Epoch 60/100
# 70/70 [==============================] - 65s 922ms/step - loss: 0.4998 - accuracy: 0.7866 - recall: 0.7562 - precision: 0.8091 - auc: 0.9538 - val_loss: 0.4485 - val_accuracy: 0.8405 - val_recall: 0.7862 - val_precision: 0.8737 - val_auc: 0.9707
# Epoch 61/100
# 70/70 [==============================] - 64s 909ms/step - loss: 0.4666 - accuracy: 0.8031 - recall: 0.7763 - precision: 0.8247 - auc: 0.9593 - val_loss: 0.3922 - val_accuracy: 0.8665 - val_recall: 0.8248 - val_precision: 0.8938 - val_auc: 0.9774
# Epoch 62/100
# 70/70 [==============================] - 65s 924ms/step - loss: 0.4699 - accuracy: 0.7964 - recall: 0.7752 - precision: 0.8171 - auc: 0.9590 - val_loss: 0.3957 - val_accuracy: 0.8582 - val_recall: 0.8238 - val_precision: 0.8987 - val_auc: 0.9781
# Epoch 63/100
# 70/70 [==============================] - 63s 907ms/step - loss: 0.4560 - accuracy: 0.8071 - recall: 0.7861 - precision: 0.8267 - auc: 0.9618 - val_loss: 0.4062 - val_accuracy: 0.8613 - val_recall: 0.8081 - val_precision: 0.8980 - val_auc: 0.9775
# Epoch 64/100
# 70/70 [==============================] - 63s 905ms/step - loss: 0.4397 - accuracy: 0.8147 - recall: 0.7901 - precision: 0.8333 - auc: 0.9638 - val_loss: 0.3803 - val_accuracy: 0.8717 - val_recall: 0.8488 - val_precision: 0.8945 - val_auc: 0.9770
# Epoch 65/100
# 70/70 [==============================] - 64s 911ms/step - loss: 0.4423 - accuracy: 0.8174 - recall: 0.7950 - precision: 0.8342 - auc: 0.9640 - val_loss: 0.3611 - val_accuracy: 0.8707 - val_recall: 0.8394 - val_precision: 0.8925 - val_auc: 0.9805
# Epoch 66/100
# 70/70 [==============================] - 63s 905ms/step - loss: 0.4136 - accuracy: 0.8279 - recall: 0.8082 - precision: 0.8444 - auc: 0.9681 - val_loss: 0.3478 - val_accuracy: 0.8801 - val_recall: 0.8488 - val_precision: 0.9075 - val_auc: 0.9824
# Epoch 67/100
# 70/70 [==============================] - 66s 942ms/step - loss: 0.4071 - accuracy: 0.8279 - recall: 0.8104 - precision: 0.8436 - auc: 0.9690 - val_loss: 0.3418 - val_accuracy: 0.8697 - val_recall: 0.8363 - val_precision: 0.8891 - val_auc: 0.9818
# Epoch 68/100
# 70/70 [==============================] - 63s 907ms/step - loss: 0.4176 - accuracy: 0.8272 - recall: 0.8102 - precision: 0.8426 - auc: 0.9678 - val_loss: 0.3805 - val_accuracy: 0.8498 - val_recall: 0.8196 - val_precision: 0.8666 - val_auc: 0.9764
# Epoch 69/100
# 70/70 [==============================] - 66s 945ms/step - loss: 0.4091 - accuracy: 0.8310 - recall: 0.8122 - precision: 0.8458 - auc: 0.9688 - val_loss: 0.3476 - val_accuracy: 0.9051 - val_recall: 0.8717 - val_precision: 0.9177 - val_auc: 0.9841
# Epoch 70/100
# 70/70 [==============================] - 65s 922ms/step - loss: 0.3840 - accuracy: 0.8370 - recall: 0.8223 - precision: 0.8529 - auc: 0.9724 - val_loss: 0.3410 - val_accuracy: 0.8811 - val_recall: 0.8551 - val_precision: 0.8972 - val_auc: 0.9820
# Epoch 71/100
# 70/70 [==============================] - 64s 910ms/step - loss: 0.3892 - accuracy: 0.8408 - recall: 0.8247 - precision: 0.8535 - auc: 0.9720 - val_loss: 0.4067 - val_accuracy: 0.8592 - val_recall: 0.8259 - val_precision: 0.8919 - val_auc: 0.9738
# Epoch 72/100
# 70/70 [==============================] - 63s 908ms/step - loss: 0.3850 - accuracy: 0.8410 - recall: 0.8234 - precision: 0.8553 - auc: 0.9725 - val_loss: 0.3251 - val_accuracy: 0.8644 - val_recall: 0.8519 - val_precision: 0.8871 - val_auc: 0.9829
# Epoch 73/100
# 70/70 [==============================] - 66s 944ms/step - loss: 0.3964 - accuracy: 0.8265 - recall: 0.8084 - precision: 0.8419 - auc: 0.9706 - val_loss: 0.3525 - val_accuracy: 0.8697 - val_recall: 0.8436 - val_precision: 0.8939 - val_auc: 0.9804
# Epoch 74/100
# 70/70 [==============================] - 63s 907ms/step - loss: 0.3687 - accuracy: 0.8493 - recall: 0.8341 - precision: 0.8614 - auc: 0.9744 - val_loss: 0.3241 - val_accuracy: 0.8728 - val_recall: 0.8498 - val_precision: 0.8927 - val_auc: 0.9839
# Epoch 75/100
# 70/70 [==============================] - 64s 912ms/step - loss: 0.3595 - accuracy: 0.8439 - recall: 0.8319 - precision: 0.8566 - auc: 0.9757 - val_loss: 0.2889 - val_accuracy: 0.8989 - val_recall: 0.8811 - val_precision: 0.9175 - val_auc: 0.9879
# Epoch 76/100
# 70/70 [==============================] - 66s 946ms/step - loss: 0.3233 - accuracy: 0.8681 - recall: 0.8576 - precision: 0.8783 - auc: 0.9807 - val_loss: 0.3297 - val_accuracy: 0.8801 - val_recall: 0.8571 - val_precision: 0.8964 - val_auc: 0.9810
# Epoch 77/100
# 70/70 [==============================] - 63s 905ms/step - loss: 0.3394 - accuracy: 0.8609 - recall: 0.8500 - precision: 0.8718 - auc: 0.9784 - val_loss: 0.2707 - val_accuracy: 0.9082 - val_recall: 0.8926 - val_precision: 0.9194 - val_auc: 0.9885
# Epoch 78/100
# 70/70 [==============================] - 67s 962ms/step - loss: 0.3367 - accuracy: 0.8681 - recall: 0.8567 - precision: 0.8758 - auc: 0.9788 - val_loss: 0.2865 - val_accuracy: 0.8989 - val_recall: 0.8759 - val_precision: 0.9101 - val_auc: 0.9875
# Epoch 79/100
# 70/70 [==============================] - 64s 916ms/step - loss: 0.3353 - accuracy: 0.8627 - recall: 0.8504 - precision: 0.8758 - auc: 0.9789 - val_loss: 0.2762 - val_accuracy: 0.9030 - val_recall: 0.8863 - val_precision: 0.9169 - val_auc: 0.9875
# Epoch 80/100
# 70/70 [==============================] - 64s 913ms/step - loss: 0.3150 - accuracy: 0.8676 - recall: 0.8547 - precision: 0.8764 - auc: 0.9813 - val_loss: 0.2534 - val_accuracy: 0.9062 - val_recall: 0.8905 - val_precision: 0.9203 - val_auc: 0.9896
# Epoch 81/100
# 70/70 [==============================] - 64s 911ms/step - loss: 0.3204 - accuracy: 0.8718 - recall: 0.8631 - precision: 0.8814 - auc: 0.9806 - val_loss: 0.2700 - val_accuracy: 0.8999 - val_recall: 0.8832 - val_precision: 0.9137 - val_auc: 0.9875
# Epoch 82/100
# 70/70 [==============================] - 65s 920ms/step - loss: 0.3274 - accuracy: 0.8663 - recall: 0.8567 - precision: 0.8748 - auc: 0.9796 - val_loss: 0.2860 - val_accuracy: 0.8999 - val_recall: 0.8770 - val_precision: 0.9151 - val_auc: 0.9861
# Epoch 83/100
# 70/70 [==============================] - 64s 909ms/step - loss: 0.3210 - accuracy: 0.8732 - recall: 0.8654 - precision: 0.8825 - auc: 0.9806 - val_loss: 0.2527 - val_accuracy: 0.9208 - val_recall: 0.9041 - val_precision: 0.9283 - val_auc: 0.9901
# Epoch 84/100
# 70/70 [==============================] - 66s 943ms/step - loss: 0.3030 - accuracy: 0.8763 - recall: 0.8669 - precision: 0.8849 - auc: 0.9827 - val_loss: 0.2481 - val_accuracy: 0.9124 - val_recall: 0.8999 - val_precision: 0.9260 - val_auc: 0.9897
# Epoch 85/100
# 70/70 [==============================] - 67s 957ms/step - loss: 0.2999 - accuracy: 0.8819 - recall: 0.8705 - precision: 0.8890 - auc: 0.9828 - val_loss: 0.2460 - val_accuracy: 0.9208 - val_recall: 0.9103 - val_precision: 0.9337 - val_auc: 0.9907
# Epoch 86/100
# 70/70 [==============================] - 64s 916ms/step - loss: 0.2858 - accuracy: 0.8873 - recall: 0.8810 - precision: 0.8952 - auc: 0.9847 - val_loss: 0.2127 - val_accuracy: 0.9291 - val_recall: 0.9145 - val_precision: 0.9430 - val_auc: 0.9933
# Epoch 87/100
# 70/70 [==============================] - 63s 907ms/step - loss: 0.2739 - accuracy: 0.8906 - recall: 0.8839 - precision: 0.8975 - auc: 0.9854 - val_loss: 0.2408 - val_accuracy: 0.9145 - val_recall: 0.9030 - val_precision: 0.9252 - val_auc: 0.9908
# Epoch 88/100
# 70/70 [==============================] - 66s 950ms/step - loss: 0.2854 - accuracy: 0.8835 - recall: 0.8752 - precision: 0.8927 - auc: 0.9843 - val_loss: 0.2065 - val_accuracy: 0.9395 - val_recall: 0.9145 - val_precision: 0.9533 - val_auc: 0.9947
# Epoch 89/100
# 70/70 [==============================] - 64s 914ms/step - loss: 0.2807 - accuracy: 0.8908 - recall: 0.8812 - precision: 0.8983 - auc: 0.9849 - val_loss: 0.2003 - val_accuracy: 0.9239 - val_recall: 0.9124 - val_precision: 0.9299 - val_auc: 0.9942
# Epoch 90/100
# 70/70 [==============================] - 66s 945ms/step - loss: 0.2731 - accuracy: 0.8937 - recall: 0.8857 - precision: 0.9016 - auc: 0.9857 - val_loss: 0.2102 - val_accuracy: 0.9312 - val_recall: 0.9218 - val_precision: 0.9364 - val_auc: 0.9936
# Epoch 91/100
# 70/70 [==============================] - 63s 907ms/step - loss: 0.2543 - accuracy: 0.8995 - recall: 0.8942 - precision: 0.9057 - auc: 0.9873 - val_loss: 0.1917 - val_accuracy: 0.9364 - val_recall: 0.9281 - val_precision: 0.9428 - val_auc: 0.9945
# Epoch 92/100
# 70/70 [==============================] - 64s 907ms/step - loss: 0.2410 - accuracy: 0.9065 - recall: 0.9000 - precision: 0.9126 - auc: 0.9888 - val_loss: 0.1785 - val_accuracy: 0.9499 - val_recall: 0.9426 - val_precision: 0.9566 - val_auc: 0.9955
# Epoch 93/100
# 70/70 [==============================] - 66s 942ms/step - loss: 0.2584 - accuracy: 0.8917 - recall: 0.8832 - precision: 0.8991 - auc: 0.9873 - val_loss: 0.1785 - val_accuracy: 0.9479 - val_recall: 0.9364 - val_precision: 0.9563 - val_auc: 0.9958
# Epoch 94/100
# 70/70 [==============================] - 61s 876ms/step - loss: 0.2412 - accuracy: 0.9033 - recall: 0.8973 - precision: 0.9095 - auc: 0.9888 - val_loss: 0.1942 - val_accuracy: 0.9426 - val_recall: 0.9385 - val_precision: 0.9504 - val_auc: 0.9935
# Epoch 95/100
# 70/70 [==============================] - 61s 876ms/step - loss: 0.2387 - accuracy: 0.9024 - recall: 0.8993 - precision: 0.9086 - auc: 0.9891 - val_loss: 0.1689 - val_accuracy: 0.9395 - val_recall: 0.9343 - val_precision: 0.9442 - val_auc: 0.9958
# Epoch 96/100
# 70/70 [==============================] - 61s 876ms/step - loss: 0.2231 - accuracy: 0.9172 - recall: 0.9123 - precision: 0.9205 - auc: 0.9898 - val_loss: 0.1831 - val_accuracy: 0.9406 - val_recall: 0.9322 - val_precision: 0.9470 - val_auc: 0.9940
# Epoch 97/100
# 70/70 [==============================] - 63s 896ms/step - loss: 0.2211 - accuracy: 0.9138 - recall: 0.9089 - precision: 0.9212 - auc: 0.9905 - val_loss: 0.1849 - val_accuracy: 0.9364 - val_recall: 0.9291 - val_precision: 0.9409 - val_auc: 0.9934
# Epoch 98/100
# 70/70 [==============================] - 61s 877ms/step - loss: 0.2407 - accuracy: 0.9069 - recall: 0.9009 - precision: 0.9121 - auc: 0.9886 - val_loss: 0.1715 - val_accuracy: 0.9301 - val_recall: 0.9260 - val_precision: 0.9447 - val_auc: 0.9956
# Epoch 99/100
# 70/70 [==============================] - 62s 892ms/step - loss: 0.2385 - accuracy: 0.9053 - recall: 0.8980 - precision: 0.9118 - auc: 0.9888 - val_loss: 0.1883 - val_accuracy: 0.9416 - val_recall: 0.9333 - val_precision: 0.9491 - val_auc: 0.9946
# Epoch 100/100
# 70/70 [==============================] - 61s 876ms/step - loss: 0.2124 - accuracy: 0.9136 - recall: 0.9089 - precision: 0.9181 - auc: 0.9912 - val_loss: 0.1606 - val_accuracy: 0.9479 - val_recall: 0.9458 - val_precision: 0.9517 - val_auc: 0.9962

# %%
metricsEval = list(model_history.history.keys())
print(metricsEval , '\n')

historyDF = pd.DataFrame(model_history.history)
historyDF.head()
historyDF.to_csv('mycsvfile.csv',index=False)
# Out:
# ['loss', 'accuracy', 'recall', 'precision', 'auc', 'val_loss', 'val_accuracy', 'val_recall', 'val_precision', 'val_auc']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axarr = plt.subplots(1, 5, figsize=(21, 8), sharex=True)

sns.set(style="ticks", font_scale=1)
sns.despine(top=True, right=True, left=False, bottom=False)

# Modify the code to create the lineplots on the same row
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[0]], ax=axarr[0], label="Validation")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[5]], ax=axarr[0], label="Training")
axarr[0].set_ylabel('Loss')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[1]], ax=axarr[1], label="Validation")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[6]], ax=axarr[1], label="Training")
axarr[1].set_ylabel('Accuracy')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[2]], ax=axarr[2], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[7]], ax=axarr[2], label="Validation")
axarr[2].set_ylabel('Precision')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[3]], ax=axarr[3], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[8]], ax=axarr[3], label="Validation")
axarr[3].set_ylabel('Recall')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[4]], ax=axarr[4], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[9]], ax=axarr[4], label="Validation")
axarr[4].set_ylabel('AUC')

# Modify the titles and labels as needed
axarr[0].set_title('Loss', fontsize=17)
axarr[1].set_title('Accuracy', fontsize=17)
axarr[2].set_title('Precision', fontsize=17)
axarr[3].set_title('Recall', fontsize=17)
axarr[4].set_title('AUC', fontsize=17)

for ax in axarr:
    ax.set_xlabel('Epochs')

plt.suptitle('Training and Validation Performance Plots', fontsize=19, weight='bold')
fig.tight_layout(pad=3.0)
plt.savefig("trainingandval.png", dpi=1080)
plt.show()

# %%
# Assuming you have test_data and test_labels for your test set
test_metrics = model.evaluate(test_data)

test_accuracy = test_metrics[1]
test_precision = test_metrics[3]
test_recall = test_metrics[2]
test_auc = test_metrics[4]

# Calculate F1 score
test_f1_score = 2 * (test_precision * test_recall) / (test_precision + test_recall)

print("Test Accuracy:", test_accuracy)
print("Test Precision:", test_precision)
print("Test Recall:", test_recall)
print("Test AUC:", test_auc)
print("Test F1 Score:", test_f1_score)
# Out:
# 16/16 [==============================] - 3s 164ms/step - loss: 0.1585 - accuracy: 0.9356 - recall: 0.9304 - precision: 0.9441 - auc: 0.9957
# Test Accuracy: 0.9355509281158447
# Test Precision: 0.9440928101539612
# Test Recall: 0.9303534030914307
# Test AUC: 0.9956815242767334
# Test F1 Score: 0.9371727527354795

# %%
# !pip install visualkeras
import visualkeras
visualkeras.layered_view(model, legend=True) # without custom font
from PIL import ImageFont

visualkeras.layered_view(model, legend=True, ) # selected font
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 13.6 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18 visualkeras-0.0.2
# <PIL.Image.Image image mode=RGBA size=933x1231>
