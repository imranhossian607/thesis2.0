# %% [markdown]
# <a href="https://colab.research.google.com/github/imranhossian607/thesis2.0/blob/main/cnn%2Cvgg16_and_vgg19_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import warnings

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow import keras
import tensorflow
import scipy
print("Num GPUs Available: ", len(tensorflow.config.list_physical_devices('GPU')))


# Set the seed value for experiment reproduci.bility.
seed = 1842
tensorflow.random.set_seed(seed)
np.random.seed(seed)
# Turn off warnings for cleaner looking notebook
warnings.simplefilter('ignore')
# Out:
# Num GPUs Available:  1

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Split the dataset into train, validation, and test sets
input_folder = '/content/drive/MyDrive/Dataset'
output_folder = 'output'

splitfolders.ratio(input_folder, output=output_folder, seed=1345, ratio=(0.7, 0.15, 0.15))

# Define data augmentation parameters
WIDTH,HEIGHT=224,224

train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.2,          # Zoom in/out by a maximum of 20%
                                   horizontal_flip=True,)

valid_datagen = ImageDataGenerator(rescale = 1./255)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# Define the directories for your training, validation, and test sets
train_dir = os.path.join(output_folder, 'train')
valid_dir = os.path.join(output_folder, 'val')
test_dir = os.path.join(output_folder, 'test')

# Apply data augmentation to the training dataset
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size = (WIDTH,HEIGHT),
    color_mode = "rgb",
    batch_size = 64,
    interpolation = "bicubic" ,
    shuffle = True ,
    class_mode='categorical'  # Change to appropriate mode for your dataset
)


# No augmentation for validation and test datasets
valid_data = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=(WIDTH,HEIGHT),   # Adjust the target size as needed
    color_mode = "rgb",
    batch_size = 64,
    interpolation = "bicubic" ,
    shuffle = True ,
    class_mode='categorical'  # Change to appropriate mode for your dataset
)

test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=(WIDTH,HEIGHT),   # Adjust the target size as needed
    color_mode = "rgb",
    batch_size = 64,
    interpolation = "bicubic" ,
    shuffle = True ,
    class_mode='categorical'  # Change to appropriate mode for your dataset
)
# Out:
# Copying files: 6400 files [36:31,  2.92 files/s]
# Found 4479 images belonging to 4 classes.
# Found 959 images belonging to 4 classes.
# Found 962 images belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

batch_1_img = train_data[0]
plt.figure(figsize=(12, 4))  # Adjust the figure size as needed

for i in range(4):
    img = batch_1_img[0][i]
    lab = batch_1_img[1][i]

    # Create a subplot for each image
    plt.subplot(1, 4, i + 1)
    plt.imshow(img)
    plt.title(f'Class: {lab}')  # Set the title to display the class label
    plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt

batch_1_img = test_data[0]
plt.figure(figsize=(12, 4))  # Adjust the figure size as needed

for i in range(4):
    img = batch_1_img[0][i]
    lab = batch_1_img[1][i]

    # Create a subplot for each image
    plt.subplot(1, 4, i + 1)
    plt.imshow(img)
    plt.title(f'Class: {lab}')  # Set the title to display the class label
    plt.axis('off')

plt.show()

# %% [markdown]
# #CNN

# %%
import tensorflow as tf
from tensorflow import keras

input_shape = (WIDTH, HEIGHT, 3)

# Define your CNN model
model = keras.models.Sequential()

model.add(keras.layers.Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu', kernel_initializer="he_normal", input_shape=input_shape))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(keras.layers.Dropout(0.20))

model.add(keras.layers.Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu', kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(keras.layers.Dropout(0.20))

model.add(keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu', kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(keras.layers.Dropout(0.20))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128, activation="relu", kernel_initializer="he_normal"))
model.add(keras.layers.Dense(64, activation="relu"))
model.add(keras.layers.Dense(4, activation="softmax"))

# Print model summary
model.summary()

# Compile the model
model.compile(
    optimizer='adam',
    loss=tf.losses.CategoricalCrossentropy(),
    metrics=["accuracy", tf.metrics.Recall(), tf.metrics.Precision(), tf.metrics.AUC()]
)

# Early stopping callback
callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# Train the model
model_history = model.fit(train_data, epochs=100, validation_data=valid_data, callbacks=[callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 16)      0
#  D)
#
#  dropout (Dropout)           (None, 112, 112, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 56, 56, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 28, 28, 64)        0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 128)               6422656
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 6454756 (24.62 MB)
# Trainable params: 6454756 (24.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 70/70 [==============================] - 95s 1s/step - loss: 1.6556 - accuracy: 0.4727 - recall: 0.2748 - precision: 0.4964 - auc: 0.7521 - val_loss: 1.1043 - val_accuracy: 0.5036 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.8117
# Epoch 2/100
# 70/70 [==============================] - 68s 977ms/step - loss: 1.0074 - accuracy: 0.5044 - recall: 0.3186 - precision: 0.5953 - auc: 0.8035 - val_loss: 1.1291 - val_accuracy: 0.5151 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.8185
# Epoch 3/100
# 70/70 [==============================] - 69s 988ms/step - loss: 0.9941 - accuracy: 0.5175 - recall: 0.3056 - precision: 0.6079 - auc: 0.8086 - val_loss: 1.0591 - val_accuracy: 0.5214 - val_recall: 0.0647 - val_precision: 0.9841 - val_auc: 0.8272
# Epoch 4/100
# 70/70 [==============================] - 72s 1s/step - loss: 0.9437 - accuracy: 0.5463 - recall: 0.3831 - precision: 0.6349 - auc: 0.8303 - val_loss: 1.0682 - val_accuracy: 0.5516 - val_recall: 0.1522 - val_precision: 0.8588 - val_auc: 0.8236
# Epoch 5/100
# 70/70 [==============================] - 70s 995ms/step - loss: 0.9334 - accuracy: 0.5555 - recall: 0.3778 - precision: 0.6566 - auc: 0.8343 - val_loss: 1.0311 - val_accuracy: 0.5287 - val_recall: 0.2836 - val_precision: 0.7535 - val_auc: 0.8306
# Epoch 6/100
# 70/70 [==============================] - 67s 955ms/step - loss: 0.9088 - accuracy: 0.5546 - recall: 0.3847 - precision: 0.6470 - auc: 0.8395 - val_loss: 1.0335 - val_accuracy: 0.5422 - val_recall: 0.1846 - val_precision: 0.8592 - val_auc: 0.8114
# Epoch 7/100
# 70/70 [==============================] - 70s 1s/step - loss: 0.9165 - accuracy: 0.5591 - recall: 0.3842 - precision: 0.6658 - auc: 0.8392 - val_loss: 1.0126 - val_accuracy: 0.5714 - val_recall: 0.2044 - val_precision: 0.8133 - val_auc: 0.8368
# Epoch 8/100
# 70/70 [==============================] - 68s 979ms/step - loss: 0.8827 - accuracy: 0.5662 - recall: 0.4021 - precision: 0.6743 - auc: 0.8493 - val_loss: 0.9244 - val_accuracy: 0.5798 - val_recall: 0.2565 - val_precision: 0.7834 - val_auc: 0.8535
# Epoch 9/100
# 70/70 [==============================] - 66s 944ms/step - loss: 0.8678 - accuracy: 0.5874 - recall: 0.4240 - precision: 0.6787 - auc: 0.8563 - val_loss: 0.9096 - val_accuracy: 0.5808 - val_recall: 0.2888 - val_precision: 0.7610 - val_auc: 0.8569
# Epoch 10/100
# 70/70 [==============================] - 70s 994ms/step - loss: 0.8592 - accuracy: 0.5910 - recall: 0.4356 - precision: 0.6793 - auc: 0.8590 - val_loss: 0.9319 - val_accuracy: 0.5829 - val_recall: 0.2690 - val_precision: 0.8088 - val_auc: 0.8609
# Epoch 11/100
# 70/70 [==============================] - 68s 979ms/step - loss: 0.8405 - accuracy: 0.6010 - recall: 0.4508 - precision: 0.6844 - auc: 0.8644 - val_loss: 0.8585 - val_accuracy: 0.6038 - val_recall: 0.3160 - val_precision: 0.7556 - val_auc: 0.8751
# Epoch 12/100
# 70/70 [==============================] - 69s 989ms/step - loss: 0.8336 - accuracy: 0.5930 - recall: 0.4637 - precision: 0.6632 - auc: 0.8651 - val_loss: 0.9115 - val_accuracy: 0.6246 - val_recall: 0.2544 - val_precision: 0.8472 - val_auc: 0.8761
# Epoch 13/100
# 70/70 [==============================] - 70s 1s/step - loss: 0
# 70/70 [==============================] - 73s 1s/step - loss: 0.3057 - accuracy: 0.8801 - recall: 0.8687 - precision: 0.8900 - auc: 0.9825 - val_loss: 0.3073 - val_accuracy: 0.8978 - val_recall: 0.8926 - val_precision: 0.9001 - val_auc: 0.9823
# Epoch 48/100
# 70/70 [==============================] - 75s 1s/step - loss: 0.3086 - accuracy: 0.8783 - recall: 0.8674 - precision: 0.8878 - auc: 0.9818 - val_loss: 0.2355 - val_accuracy: 0.9072 - val_recall: 0.8957 - val_precision: 0.9197 - val_auc: 0.9906
# Epoch 49/100
# 70/70 [==============================] - 73s 1s/step - loss: 0.3048 - accuracy: 0.8747 - recall: 0.8660 - precision: 0.8844 - auc: 0.9826 - val_loss: 0.2383 - val_accuracy: 0.9124 - val_recall: 0.9051 - val_precision: 0.9214 - val_auc: 0.9904
# Epoch 50/100
# 70/70 [==============================] - 77s 1s/step - loss: 0.2965 - accuracy: 0.8848 - recall: 0.8721 - precision: 0.8934 - auc: 0.9832 - val_loss: 0.2739 - val_accuracy: 0.8884 - val_recall: 0.8874 - val_precision: 0.8967 - val_auc: 0.9862
# Epoch 51/100
# 70/70 [==============================] - 72s 1s/step - loss: 0.2757 - accuracy: 0.8897 - recall: 0.8821 - precision: 0.8969 - auc: 0.9854 - val_loss: 0.2466 - val_accuracy: 0.8989 - val_recall: 0.8968 - val_precision: 0.9024 - val_auc: 0.9888
# Epoch 52/100
# 70/70 [==============================] - 75s 1s/step - loss: 0.2497 - accuracy: 0.8982 - recall: 0.8913 - precision: 0.9062 - auc: 0.9882 - val_loss: 0.2196 - val_accuracy: 0.9166 - val_recall: 0.9145 - val_precision: 0.9290 - val_auc: 0.9910
# Epoch 53/100
# 70/70 [==============================] - 74s 1s/step - loss: 0.2660 - accuracy: 0.8939 - recall: 0.8861 - precision: 0.9006 - auc: 0.9865 - val_loss: 0.2308 - val_accuracy: 0.9041 - val_recall: 0.8999 - val_precision: 0.9103 - val_auc: 0.9897
# Epoch 54/100
# 70/70 [==============================] - 74s 1s/step - loss: 0.2624 - accuracy: 0.8973 - recall: 0.8895 - precision: 0.9048 - auc: 0.9864 - val_loss: 0.2030 - val_accuracy: 0.9301 - val_recall: 0.9218 - val_precision: 0.9394 - val_auc: 0.9930
# Epoch 55/100
# 70/70 [==============================] - 76s 1s/step - loss: 0.2500 - accuracy: 0.9038 - recall: 0.8969 - precision: 0.9121 - auc: 0.9882 - val_loss: 0.2276 - val_accuracy: 0.9166 - val_recall: 0.9072 - val_precision: 0.9216 - val_auc: 0.9903
# Epoch 56/100
# 70/70 [==============================] - 72s 1s/step - loss: 0.2236 - accuracy: 0.9187 - recall: 0.9140 - precision: 0.9233 - auc: 0.9898 - val_loss: 0.2019 - val_accuracy: 0.9249 - val_recall: 0.9197 - val_precision: 0.9274 - val_auc: 0.9923
# Epoch 57/100
# 70/70 [==============================] - 80s 1s/step - loss: 0.2149 - accuracy: 0.9187 - recall: 0.9138 - precision: 0.9237 - auc: 0.9909 - val_loss: 0.2050 - val_accuracy: 0.9166 - val_recall: 0.9114 - val_precision: 0.9200 - val_auc: 0.9918
# Epoch 58/100
100
# 70/70 [==============================] - 72s 1s/step - loss: 0.1174 - accuracy: 0.9585 - recall: 0.9567 - precision: 0.9601 - auc: 0.9965 - val_loss: 0.0980 - val_accuracy: 0.9625 - val_recall: 0.9604 - val_precision: 0.9654 - val_auc: 0.9984
# Epoch 92/100
# 70/70 [==============================] - 69s 983ms/step - loss: 0.0909 - accuracy: 0.9649 - recall: 0.9643 - precision: 0.9664 - auc: 0.9981 - val_loss: 0.0726 - val_accuracy: 0.9708 - val_recall: 0.9708 - val_precision: 0.9718 - val_auc: 0.9990
# Epoch 93/100
# 70/70 [==============================] - 68s 970ms/step - loss: 0.0725 - accuracy: 0.9754 - recall: 0.9745 - precision: 0.9763 - auc: 0.9985 - val_loss: 0.1177 - val_accuracy: 0.9562 - val_recall: 0.9562 - val_precision: 0.9582 - val_auc: 0.9966
# Epoch 94/100
# 70/70 [==============================] - 70s 999ms/step - loss: 0.1045 - accuracy: 0.9620 - recall: 0.9609 - precision: 0.9631 - auc: 0.9971 - val_loss: 0.0988 - val_accuracy: 0.9656 - val_recall: 0.9656 - val_precision: 0.9666 - val_auc: 0.9970
# Epoch 95/100
# 70/70 [==============================] - 72s 1s/step - loss: 0.0864 - accuracy: 0.9687 - recall: 0.9667 - precision: 0.9691 - auc: 0.9982 - val_loss: 0.0890 - val_accuracy: 0.9677 - val_recall: 0.9656 - val_precision: 0.9676 - val_auc: 0.9985
# Epoch 96/100
# 70/70 [==============================] - 69s 988ms/step - loss: 0.0850 - accuracy: 0.9705 - recall: 0.9687 - precision: 0.9716 - auc: 0.9981 - val_loss: 0.1097 - val_accuracy: 0.9552 - val_recall: 0.9552 - val_precision: 0.9572 - val_auc: 0.9979
# Epoch 97/100
# 70/70 [==============================] - 70s 1s/step - loss: 0.0888 - accuracy: 0.9685 - recall: 0.9681 - precision: 0.9694 - auc: 0.9980 - val_loss: 0.0946 - val_accuracy: 0.9635 - val_recall: 0.9635 - val_precision: 0.9645 - val_auc: 0.9979
# Epoch 98/100
# 70/70 [==============================] - 68s 968ms/step - loss: 0.0915 - accuracy: 0.9683 - recall: 0.9672 - precision: 0.9687 - auc: 0.9975 - val_loss: 0.1158 - val_accuracy: 0.9593 - val_recall: 0.9583 - val_precision: 0.9603 - val_auc: 0.9968
# Epoch 99/100
# 70/70 [==============================] - 72s 1s/step - loss: 0.0952 - accuracy: 0.9663 - recall: 0.9656 - precision: 0.9676 - auc: 0.9974 - val_loss: 0.0832 - val_accuracy: 0.9750 - val_recall: 0.9739 - val_precision: 0.9770 - val_auc: 0.9980
# Epoch 100/100
# 70/70 [==============================] - 68s 966ms/step - loss: 0.0917 - accuracy: 0.9696 - recall: 0.9685 - precision: 0.9703 - auc: 0.9973 - val_loss: 0.0900 - val_accuracy: 0.9708 - val_recall: 0.9708 - val_precision: 0.9718 - val_auc: 0.9979

# %%
metricsEval = list(model_history.history.keys())
print(metricsEval , '\n')

historyDF = pd.DataFrame(model_history.history)
historyDF.head()
historyDF.to_csv('mycsvfile.csv',index=False)
# Out:
# ['loss', 'accuracy', 'recall', 'precision', 'auc', 'val_loss', 'val_accuracy', 'val_recall', 'val_precision', 'val_auc']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axarr = plt.subplots(1, 5, figsize=(21, 8), sharex=True)

sns.set(style="ticks", font_scale=1)
sns.despine(top=True, right=True, left=False, bottom=False)

# Modify the code to create the lineplots on the same row
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[0]], ax=axarr[0], label="Validation")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[5]], ax=axarr[0], label="Training")
axarr[0].set_ylabel('Loss')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[1]], ax=axarr[1], label="Validation")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[6]], ax=axarr[1], label="Training")
axarr[1].set_ylabel('Accuracy')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[2]], ax=axarr[2], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[7]], ax=axarr[2], label="Validation")
axarr[2].set_ylabel('Precision')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[3]], ax=axarr[3], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[8]], ax=axarr[3], label="Validation")
axarr[3].set_ylabel('Recall')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[4]], ax=axarr[4], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[9]], ax=axarr[4], label="Validation")
axarr[4].set_ylabel('AUC')

# Modify the titles and labels as needed
axarr[0].set_title('Loss', fontsize=17)
axarr[1].set_title('Accuracy', fontsize=17)
axarr[2].set_title('Precision', fontsize=17)
axarr[3].set_title('Recall', fontsize=17)
axarr[4].set_title('AUC', fontsize=17)

for ax in axarr:
    ax.set_xlabel('Epochs')

plt.suptitle('Training and Validation Performance Plots', fontsize=19, weight='bold')
fig.tight_layout(pad=3.0)
plt.savefig("trainingandval.png", dpi=1080)
plt.show()

# %%
# Assuming you have test_data and test_labels for your test set
test_metrics = model.evaluate(test_data)

test_accuracy = test_metrics[1]
test_precision = test_metrics[3]
test_recall = test_metrics[2]
test_auc = test_metrics[4]

# Calculate F1 score
test_f1_score = 2 * (test_precision * test_recall) / (test_precision + test_recall)

print("Test Accuracy:", test_accuracy)
print("Test Precision:", test_precision)
print("Test Recall:", test_recall)
print("Test AUC:", test_auc)
print("Test F1 Score:", test_f1_score)
# Out:
# 16/16 [==============================] - 3s 175ms/step - loss: 0.0638 - accuracy: 0.9761 - recall: 0.9761 - precision: 0.9791 - auc: 0.9993
# Test Accuracy: 0.9760915040969849
# Test Precision: 0.9791449308395386
# Test Recall: 0.9760915040969849
# Test AUC: 0.9992997646331787
# Test F1 Score: 0.9776158332515231

# %%
# !pip install visualkeras
import visualkeras
visualkeras.layered_view(model, legend=True) # without custom font
from PIL import ImageFont

visualkeras.layered_view(model, legend=True, ) # selected font
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.17-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.17 visualkeras-0.0.2
# <PIL.Image.Image image mode=RGBA size=933x1231>

# %% [markdown]
# #vgg 16

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Model

# Create the VGG16 model
vgg = VGG16(input_shape=(WIDTH,HEIGHT, 3), weights='imagenet', include_top=False)


# Flatten the VGG16 output
x = Flatten()(vgg.output)

# Add a Dense layer for classification
prediction = Dense(4, activation='softmax')(x)

# Create the final model
model = Model(inputs=vgg.input, outputs=prediction)

# Print model summary
model.summary()

# Compile the model
model.compile(
    optimizer='adam',
    loss=tf.losses.CategoricalCrossentropy(),
    metrics=["accuracy", tf.metrics.Recall(), tf.metrics.Precision(), tf.metrics.AUC()]
)

# Define the EarlyStopping callback
callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# Assuming you have 'train_data' and 'valid_data' defined, you can now train the model
model_history = model.fit(train_data, epochs=100, validation_data=valid_data, callbacks=[callback])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_3 (Dense)             (None, 4)                 100356
#
# =================================================================
# Total params: 14815044 (56.51 MB)
# Trainable params: 14815044 (56.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 70/70 [==============================] - 133s 2s/step - loss: 1.7569 - accuracy: 0.4762 - recall_1: 0.2632 - precision_1: 0.4866 - auc_1: 0.7593 - val_loss: 1.0371 - val_accuracy: 0.5005 - val_recall_1: 0.5005 - val_precision_1: 0.5005 - val_auc_1: 0.7828
# Epoch 2/100
# 70/70 [==============================] - 89s 1s/step - loss: 1.0408 - accuracy: 0.4930 - recall_1: 0.2393 - precision_1: 0.4942 - auc_1: 0.7786 - val_loss: 1.0375 - val_accuracy: 0.5005 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_auc_1: 0.7831
# Epoch 3/100
# 70/70 [==============================] - 89s 1s/step - loss: 1.0413 - accuracy: 0.4981 - recall_1: 0.2266 - precision_1: 0.5163 - auc_1: 0.7808 - val_loss: 1.0337 - val_accuracy: 0.5005 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_auc_1: 0.7881
# Epoch 4/100
# 70/70 [==============================] - 88s 1s/step - loss: 1.0396 - accuracy: 0.5001 - recall_1: 0.2257 - precision_1: 0.5063 - auc_1: 0.7799 - val_loss: 1.0391 - val_accuracy: 0.5005 - val_recall_1: 0.0125 - val_precision_1: 0.5455 - val_auc_1: 0.7863
# Epoch 5/100
# 70/70 [==============================] - 95s 1s/step - loss: 1.0475 - accuracy: 0.4910 - recall_1: 0.2373 - precision_1: 0.5057 - auc_1: 0.7791 - val_loss: 1.0415 - val_accuracy: 0.5005 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_auc_1: 0.7762
# Epoch 6/100
# 70/70 [==============================] - 88s 1s/step - loss: 1.0415 - accuracy: 0.4954 - recall_1: 0.2237 - precision_1: 0.4817 - auc_1: 0.7767 - val_loss: 1.0361 - val_accuracy: 0.5005 - val_recall_1: 0.5005 - val_precision_1: 0.5005 - val_auc_1: 0.7863
# Epoch 7/100
# 70/70 [==============================] - 89s 1s/step - loss: 1.0415 - accuracy: 0.4889 - recall_1: 0.2478 - precision_1: 0.4998 - auc_1: 0.7806 - val_loss: 1.0453 - val_accuracy: 0.5005 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_auc_1: 0.7753
# Epoch 8/100
# 70/70 [==============================] - 87s 1s/step - loss: 1.0399 - accuracy: 0.5001 - recall_1: 0.2664 - precision_1: 0.5055 - auc_1: 0.7803 - val_loss: 1.0360 - val_accuracy: 0.5005 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_auc_1: 0.7807
# Epoch 9/100
# 70/70 [==============================] - 87s 1s/step - loss: 1.0371 - accuracy: 0.5001 - recall_1: 0.2532 - precision_1: 0.5063 - auc_1: 0.7814 - val_loss: 1.0330 - val_accuracy: 0.5005 - val_recall_1: 0.5005 - val_precision_1: 0.5005 - val_auc_1: 0.7829
# Epoch 10/100
# 70/70 [==============================] - 90s 1s/step - loss: 1.0389 - accuracy: 0.5001 - recall_1: 0.2579 - precision_1: 0.5022 - auc_1: 0.7782 - val_loss: 1.0343 - val_accuracy: 0.5005 - val_recall_1: 0.5005 - val_precision_1: 0.5005 - val_auc_1: 0.7807
# Epoch 11/100
# 70/70 [==============================] - 88s 1s/step - loss: 1.0375 - accuracy: 0.5001 - recall_1: 0.2559 - precision_1: 0.5075 - auc_1: 0.7811 - val_loss: 1.0338 - val_accuracy: 0.5005 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_auc_1: 0.7834
# Epoch 12/100
# 70/70 [==============================] - 90s 1s/step - loss: 1.0378 - accuracy: 0.5001 - recall_1: 0.2326 - precision_1: 0.4983 - auc_1: 0.7791 - val_loss: 1.0362 - val_accuracy: 0.5005 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_auc_1: 0.7804
# Epoch 13/100
# 70/70 [==============================] - 88s 1s/step - loss: 1.0400 - accuracy: 0.4994 - recall_1: 0.2154 - precision_1: 0.4903 - auc_1: 0.7778 - val_loss: 1.0376 - val_accuracy: 0.5005 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_auc_1: 0.7807
# Epoch 14/100
# 70/70 [==============================] - 90s 1s/step - loss: 1.0404 - accuracy: 0.4974 - recall_1: 0.2710 - precision_1: 0.4909 - auc_1: 0.7778 - val_loss: 1.0332 - val_accuracy: 0.5005 - val_recall_1: 0.5005 - val_precision_1: 0.5005 - val_auc_1: 0.7809
# Epoch 15/100
# 70/70 [==============================] - 89s 1s/step - loss: 1.0374 - accuracy: 0.5001 - recall_1: 0.1998 - precision_1: 0.4822 - auc_1: 0.7803 - val_loss: 1.0335 - val_accuracy: 0.5005 - val_recall_1: 0.5005 - val_precision_1: 0.5005 - val_auc_1: 0.7807
# Epoch 16/100
# 70/70 [==============================] - 86s 1s/step - loss: 1.0382 - accuracy: 0.5001 - recall_1: 0.2612 - precision_1: 0.4943 - auc_1: 0.7778 - val_loss: 1.0340 - val_accuracy: 0.5005 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_auc_1: 0.7807
# Epoch 17/100
# 70/70 [==============================] - 91s 1s/step - loss: 1.0363 - accuracy: 0.5001 - recall_1: 0.1648 - precision_1: 0.4993 - auc_1: 0.7791 - val_loss: 1.0360 - val_accuracy: 0.5005 - val_recall_1: 0.5005 - val_precision_1: 0.5005 - val_auc_1: 0.7807
# Epoch 18/100
# 70/70 [==============================] - 87s 1s/step - loss: 1.0393 - accuracy: 0.5001 - recall_1: 0.2387 - precision_1: 0.4859 - auc_1: 0.7772 - val_loss: 1.0356 - val_accuracy: 0.5005 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_auc_1: 0.7807
# Epoch 19/100
# 70/70 [==============================] - 87s 1s/step - loss: 1.0369 - accuracy: 0.5001 - recall_1: 0.3244 - precision_1: 0.4937 - auc_1: 0.7788 - val_loss: 1.0332 - val_accuracy: 0.5005 - val_recall_1: 0.5005 - val_precision_1: 0.5005 - val_auc_1: 0.7807

# %%
metricsEval = list(model_history.history.keys())
print(metricsEval , '\n')

historyDF = pd.DataFrame(model_history.history)
historyDF.head()
historyDF.to_csv('mycsvfile.csv',index=False)
# Out:
# ['loss', 'accuracy', 'recall_1', 'precision_1', 'auc_1', 'val_loss', 'val_accuracy', 'val_recall_1', 'val_precision_1', 'val_auc_1']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axarr = plt.subplots(1, 5, figsize=(21, 8), sharex=True)

sns.set(style="ticks", font_scale=1)
sns.despine(top=True, right=True, left=False, bottom=False)

# Modify the code to create the lineplots on the same row
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[0]], ax=axarr[0], label="Validation")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[5]], ax=axarr[0], label="Training")
axarr[0].set_ylabel('Loss')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[1]], ax=axarr[1], label="Validation")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[6]], ax=axarr[1], label="Training")
axarr[1].set_ylabel('Accuracy')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[2]], ax=axarr[2], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[7]], ax=axarr[2], label="Validation")
axarr[2].set_ylabel('Precision')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[3]], ax=axarr[3], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[8]], ax=axarr[3], label="Validation")
axarr[3].set_ylabel('Recall')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[4]], ax=axarr[4], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[9]], ax=axarr[4], label="Validation")
axarr[4].set_ylabel('AUC')

# Modify the titles and labels as needed
axarr[0].set_title('Loss', fontsize=17)
axarr[1].set_title('Accuracy', fontsize=17)
axarr[2].set_title('Precision', fontsize=17)
axarr[3].set_title('Recall', fontsize=17)
axarr[4].set_title('AUC', fontsize=17)

for ax in axarr:
    ax.set_xlabel('Epochs')

plt.suptitle('Training and Validation Performance Plots', fontsize=19, weight='bold')
fig.tight_layout(pad=3.0)
plt.savefig("trainingandval.png", dpi=1080)
plt.show()

# %%
# Assuming you have test_data and test_labels for your test set
test_metrics = model.evaluate(test_data)

test_accuracy = test_metrics[1]
test_precision = test_metrics[3]
test_recall = test_metrics[2]
test_auc = test_metrics[4]

# Calculate F1 score
test_f1_score = 2 * (test_precision * test_recall) / (test_precision + test_recall)

print("Test Accuracy:", test_accuracy)
print("Test Precision:", test_precision)
print("Test Recall:", test_recall)
print("Test AUC:", test_auc)
print("Test F1 Score:", test_f1_score)
# Out:
# 16/16 [==============================] - 5s 301ms/step - loss: 1.0414 - accuracy: 0.4990 - recall_1: 0.4990 - precision_1: 0.4990 - auc_1: 0.7831
# Test Accuracy: 0.4989604949951172
# Test Precision: 0.4989604949951172
# Test Recall: 0.4989604949951172
# Test AUC: 0.7831315398216248
# Test F1 Score: 0.4989604949951172

# %%
import visualkeras
visualkeras.layered_view(model, legend=True) # without custom font
from PIL import ImageFont

visualkeras.layered_view(model, legend=True, ) # selected font
# Out:
# <PIL.Image.Image image mode=RGBA size=1445x1231>

# %% [markdown]
# #vgg 19

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Model

# Create the VGG19 model
vgg = VGG19(input_shape=(WIDTH, HEIGHT, 3), weights='imagenet', include_top=False)

# Flatten the VGG19 output
x = Flatten()(vgg.output)

# Add a Dense layer for classification
prediction = Dense(4, activation='softmax')(x)

# Create the final model
model = Model(inputs=vgg.input, outputs=prediction)

# Print model summary
model.summary()

# Compile the model
model.compile(
    optimizer='adam',
    loss=tf.losses.CategoricalCrossentropy(),
    metrics=["accuracy", tf.metrics.Recall(), tf.metrics.Precision(), tf.metrics.AUC()]
)

# Define the EarlyStopping callback
callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# Assuming you have 'train_data' and 'valid_data' defined, you can now train the model
model_history = model.fit(train_data, epochs=100, validation_data=valid_data, callbacks=[callback])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 4)                 100356
#
# =================================================================
# Total params: 20124740 (76.77 MB)
# Trainable params: 20124740 (76.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 70/70 [==============================] - 99s 1s/step - loss: 2.0091 - accuracy: 0.4744 - recall_2: 0.2858 - precision_2: 0.4893 - auc_2: 0.7606 - val_loss: 1.0472 - val_accuracy: 0.5005 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_auc_2: 0.7846
# Epoch 2/100
# 70/70 [==============================] - 92s 1s/step - loss: 1.0433 - accuracy: 0.4923 - recall_2: 0.2791 - precision_2: 0.4968 - auc_2: 0.7796 - val_loss: 1.0529 - val_accuracy: 0.3504 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_auc_2: 0.7306
# Epoch 3/100
# 70/70 [==============================] - 95s 1s/step - loss: 1.0426 - accuracy: 0.4990 - recall_2: 0.2851 - precision_2: 0.4865 - auc_2: 0.7774 - val_loss: 1.0361 - val_accuracy: 0.5005 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_auc_2: 0.7807
# Epoch 4/100
# 70/70 [==============================] - 92s 1s/step - loss: 1.0407 - accuracy: 0.5001 - recall_2: 0.2507 - precision_2: 0.5011 - auc_2: 0.7791 - val_loss: 1.0388 - val_accuracy: 0.5005 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_auc_2: 0.7813
# Epoch 5/100
# 70/70 [==============================] - 94s 1s/step - loss: 1.0467 - accuracy: 0.4829 - recall_2: 0.1889 - precision_2: 0.4936 - auc_2: 0.7773 - val_loss: 1.0333 - val_accuracy: 0.5005 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_auc_2: 0.7807
# Epoch 6/100
# 70/70 [==============================] - 93s 1s/step - loss: 1.0415 - accuracy: 0.4907 - recall_2: 0.2331 - precision_2: 0.5150 - auc_2: 0.7809 - val_loss: 1.0366 - val_accuracy: 0.5005 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_auc_2: 0.7807
# Epoch 7/100
# 70/70 [==============================] - 94s 1s/step - loss: 1.0399 - accuracy: 0.5001 - recall_2: 0.2411 - precision_2: 0.5114 - auc_2: 0.7799 - val_loss: 1.0341 - val_accuracy: 0.5005 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_auc_2: 0.7807
# Epoch 8/100
# 70/70 [==============================] - 95s 1s/step - loss: 1.0378 - accuracy: 0.5001 - recall_2: 0.2605 - precision_2: 0.5059 - auc_2: 0.7816 - val_loss: 1.0480 - val_accuracy: 0.5005 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_auc_2: 0.7807
# Epoch 9/100
# 70/70 [==============================] - 94s 1s/step - loss: 1.0439 - accuracy: 0.5001 - recall_2: 0.2427 - precision_2: 0.4995 - auc_2: 0.7797 - val_loss: 1.0389 - val_accuracy: 0.5005 - val_recall_2: 0.5005 - val_precision_2: 0.5005 - val_auc_2: 0.7807
# Epoch 10/100
# 70/70 [==============================] - 95s 1s/step - loss: 1.0403 - accuracy: 0.5001 - recall_2: 0.2708 - precision_2: 0.5122 - auc_2: 0.7816 - val_loss: 1.0372 - val_accuracy: 0.5005 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_auc_2: 0.7807
# Epoch 11/100
# 70/70 [==============================] - 93s 1s/step - loss: 1.0394 - accuracy: 0.5001 - recall_2: 0.2543 - precision_2: 0.4961 - auc_2: 0.7789 - val_loss: 1.0338 - val_accuracy: 0.5005 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - val_auc_2: 0.7969
# Epoch 12/100
# 70/70 [==============================] - 94s 1s/step - loss: 1.0335 - accuracy: 0.5001 - recall_2: 0.2320 - precision_2: 0.5250 - auc_2: 0.7855 - val_loss: 1.0141 - val_accuracy: 0.5005 - val_recall_2: 0.4651 - val_precision_2: 0.5210 - val_auc_2: 0.8099
# Epoch 13/100
# 70/70 [==============================] - 92s 1s/step - loss: 0.9837 - accuracy: 0.5162 - recall_2: 0.3278 - precision_2: 0.6066 - auc_2: 0.8097 - val_loss: 0.9263 - val_accuracy: 0.5610 - val_recall_2: 0.3097 - val_precision_2: 0.7279 - val_auc_2: 0.8349
# Epoch 14/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.9891 - accuracy: 0.5048 - recall_2: 0.3112 - precision_2: 0.6174 - auc_2: 0.8086 - val_loss: 0.9588 - val_accuracy: 0.5120 - val_recall_2: 0.2742 - val_precision_2: 0.7450 - val_auc_2: 0.8215
# Epoch 15/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.9484 - accuracy: 0.5253 - recall_2: 0.3387 - precision_2: 0.6433 - auc_2: 0.8227 - val_loss: 0.9363 - val_accuracy: 0.5422 - val_recall_2: 0.3566 - val_precision_2: 0.6813 - val_auc_2: 0.8323
# Epoch 16/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.9350 - accuracy: 0.5419 - recall_2: 0.3418 - precision_2: 0.6691 - auc_2: 0.8293 - val_loss: 0.9325 - val_accuracy: 0.5547 - val_recall_2: 0.3660 - val_precision_2: 0.6623 - val_auc_2: 0.8340
# Epoch 17/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.9242 - accuracy: 0.5501 - recall_2: 0.3818 - precision_2: 0.6397 - auc_2: 0.8333 - val_loss: 0.9104 - val_accuracy: 0.5620 - val_recall_2: 0.2888 - val_precision_2: 0.7406 - val_auc_2: 0.8385
# Epoch 18/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.9152 - accuracy: 0.5548 - recall_2: 0.3380 - precision_2: 0.6777 - auc_2: 0.8367 - val_loss: 0.8947 - val_accuracy: 0.5610 - val_recall_2: 0.2857 - val_precision_2: 0.7173 - val_auc_2: 0.8422
# Epoch 19/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.9103 - accuracy: 0.5483 - recall_2: 0.3490 - precision_2: 0.6598 - auc_2: 0.8374 - val_loss: 0.9516 - val_accuracy: 0.5401 - val_recall_2: 0.4348 - val_precision_2: 0.6043 - val_auc_2: 0.8349
# Epoch 20/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.9037 - accuracy: 0.5515 - recall_2: 0.3809 - precision_2: 0.6544 - auc_2: 0.8409 - val_loss: 0.9471 - val_accuracy: 0.5339 - val_recall_2: 0.4411 - val_precision_2: 0.5941 - val_auc_2: 0.8378
# Epoch 21/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.8988 - accuracy: 0.5591 - recall_2: 0.3896 - precision_2: 0.6543 - auc_2: 0.8428 - val_loss: 0.8811 - val_accuracy: 0.5474 - val_recall_2: 0.3034 - val_precision_2: 0.6847 - val_auc_2: 0.8451
# Epoch 22/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.8851 - accuracy: 0.5620 - recall_2: 0.3827 - precision_2: 0.6729 - auc_2: 0.8478 - val_loss: 0.9143 - val_accuracy: 0.5693 - val_recall_2: 0.5068 - val_precision_2: 0.5993 - val_auc_2: 0.8466
# Epoch 23/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.8715 - accuracy: 0.5762 - recall_2: 0.4108 - precision_2: 0.6740 - auc_2: 0.8533 - val_loss: 0.8490 - val_accuracy: 0.5912 - val_recall_2: 0.3608 - val_precision_2: 0.7105 - val_auc_2: 0.8604
# Epoch 24/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.8559 - accuracy: 0.5874 - recall_2: 0.4284 - precision_2: 0.6839 - auc_2: 0.8595 - val_loss: 0.8595 - val_accuracy: 0.5892 - val_recall_2: 0.4275 - val_precision_2: 0.6766 - val_auc_2: 0.8589
# Epoch 25/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.8491 - accuracy: 0.5867 - recall_2: 0.4445 - precision_2: 0.6652 - auc_2: 0.8614 - val_loss: 0.8471 - val_accuracy: 0.5965 - val_recall_2: 0.5130 - val_precision_2: 0.6578 - val_auc_2: 0.8664
# Epoch 26/100
# 70/70 [==============================] - 92s 1s/step - loss: 0.8515 - accuracy: 0.5881 - recall_2: 0.4416 - precision_2: 0.6701 - auc_2: 0.8610 - val_loss: 0.8554 - val_accuracy: 0.5954 - val_recall_2: 0.3754 - val_precision_2: 0.7186 - val_auc_2: 0.8626
# Epoch 27/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.8393 - accuracy: 0.6010 - recall_2: 0.4454 - precision_2: 0.6697 - auc_2: 0.8651 - val_loss: 0.8442 - val_accuracy: 0.5923 - val_recall_2: 0.3639 - val_precision_2: 0.7196 - val_auc_2: 0.8644
# Epoch 28/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.8314 - accuracy: 0.6079 - recall_2: 0.4644 - precision_2: 0.6786 - auc_2: 0.8680 - val_loss: 0.8661 - val_accuracy: 0.5714 - val_recall_2: 0.5193 - val_precision_2: 0.5936 - val_auc_2: 0.8569
# Epoch 29/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.8336 - accuracy: 0.5946 - recall_2: 0.4590 - precision_2: 0.6739 - auc_2: 0.8673 - val_loss: 0.8652 - val_accuracy: 0.5787 - val_recall_2: 0.4421 - val_precision_2: 0.6473 - val_auc_2: 0.8606
# Epoch 30/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.8124 - accuracy: 0.6140 - recall_2: 0.4930 - precision_2: 0.6881 - auc_2: 0.8748 - val_loss: 0.8080 - val_accuracy: 0.6361 - val_recall_2: 0.4661 - val_precision_2: 0.7073 - val_auc_2: 0.8781
# Epoch 31/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.8086 - accuracy: 0.6247 - recall_2: 0.5039 - precision_2: 0.6873 - auc_2: 0.8770 - val_loss: 0.8078 - val_accuracy: 0.6163 - val_recall_2: 0.4244 - val_precision_2: 0.7373 - val_auc_2: 0.8778
# Epoch 32/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.8052 - accuracy: 0.6162 - recall_2: 0.5052 - precision_2: 0.6806 - auc_2: 0.8773 - val_loss: 0.8356 - val_accuracy: 0.6152 - val_recall_2: 0.4035 - val_precision_2: 0.7457 - val_auc_2: 0.8721
# Epoch 33/100
# 70/70 [==============================] - 92s 1s/step - loss: 0.8206 - accuracy: 0.6035 - recall_2: 0.4800 - precision_2: 0.6817 - auc_2: 0.8719 - val_loss: 0.7917 - val_accuracy: 0.6340 - val_recall_2: 0.4797 - val_precision_2: 0.7233 - val_auc_2: 0.8823
# Epoch 34/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.7853 - accuracy: 0.6260 - recall_2: 0.5186 - precision_2: 0.6980 - auc_2: 0.8837 - val_loss: 0.7998 - val_accuracy: 0.6434 - val_recall_2: 0.5787 - val_precision_2: 0.6711 - val_auc_2: 0.8822
# Epoch 35/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.7759 - accuracy: 0.6388 - recall_2: 0.5428 - precision_2: 0.6994 - auc_2: 0.8871 - val_loss: 0.7839 - val_accuracy: 0.6403 - val_recall_2: 0.5881 - val_precision_2: 0.6845 - val_auc_2: 0.8869
# Epoch 36/100
# 70/70 [==============================] - 92s 1s/step - loss: 0.7649 - accuracy: 0.6450 - recall_2: 0.5582 - precision_2: 0.7026 - auc_2: 0.8907 - val_loss: 0.7403 - val_accuracy: 0.6538 - val_recall_2: 0.5850 - val_precision_2: 0.7004 - val_auc_2: 0.8981
# Epoch 37/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.7549 - accuracy: 0.6524 - recall_2: 0.5678 - precision_2: 0.7040 - auc_2: 0.8937 - val_loss: 0.7646 - val_accuracy: 0.6319 - val_recall_2: 0.5610 - val_precision_2: 0.6978 - val_auc_2: 0.8904
# Epoch 38/100
# 70/70 [==============================] - 92s 1s/step - loss: 0.7546 - accuracy: 0.6457 - recall_2: 0.5673 - precision_2: 0.6983 - auc_2: 0.8931 - val_loss: 0.7386 - val_accuracy: 0.6590 - val_recall_2: 0.5506 - val_precision_2: 0.7364 - val_auc_2: 0.8988
# Epoch 39/100
# 70/70 [==============================] - 92s 1s/step - loss: 0.7220 - accuracy: 0.6642 - recall_2: 0.5903 - precision_2: 0.7156 - auc_2: 0.9023 - val_loss: 0.7098 - val_accuracy: 0.6767 - val_recall_2: 0.5693 - val_precision_2: 0.7408 - val_auc_2: 0.9075
# Epoch 40/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.6970 - accuracy: 0.6870 - recall_2: 0.6142 - precision_2: 0.7342 - auc_2: 0.9096 - val_loss: 0.8295 - val_accuracy: 0.6090 - val_recall_2: 0.5735 - val_precision_2: 0.6315 - val_auc_2: 0.8748
# Epoch 41/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.7117 - accuracy: 0.6794 - recall_2: 0.6182 - precision_2: 0.7228 - auc_2: 0.9061 - val_loss: 0.6949 - val_accuracy: 0.6924 - val_recall_2: 0.6319 - val_precision_2: 0.7257 - val_auc_2: 0.9117
# Epoch 42/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.7095 - accuracy: 0.6781 - recall_2: 0.6082 - precision_2: 0.7180 - auc_2: 0.9064 - val_loss: 0.7004 - val_accuracy: 0.6872 - val_recall_2: 0.6288 - val_precision_2: 0.7213 - val_auc_2: 0.9116
# Epoch 43/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.6648 - accuracy: 0.6964 - recall_2: 0.6332 - precision_2: 0.7368 - auc_2: 0.9172 - val_loss: 0.7281 - val_accuracy: 0.6726 - val_recall_2: 0.6434 - val_precision_2: 0.6886 - val_auc_2: 0.9073
# Epoch 44/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.6670 - accuracy: 0.7124 - recall_2: 0.6528 - precision_2: 0.7393 - auc_2: 0.9184 - val_loss: 0.7070 - val_accuracy: 0.6986 - val_recall_2: 0.6538 - val_precision_2: 0.7240 - val_auc_2: 0.9096
# Epoch 45/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.6697 - accuracy: 0.6979 - recall_2: 0.6432 - precision_2: 0.7351 - auc_2: 0.9170 - val_loss: 0.6564 - val_accuracy: 0.7143 - val_recall_2: 0.6601 - val_precision_2: 0.7465 - val_auc_2: 0.9220
# Epoch 46/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.6342 - accuracy: 0.7191 - recall_2: 0.6743 - precision_2: 0.7498 - auc_2: 0.9257 - val_loss: 0.6894 - val_accuracy: 0.7018 - val_recall_2: 0.6434 - val_precision_2: 0.7363 - val_auc_2: 0.9153
# Epoch 47/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.6509 - accuracy: 0.7118 - recall_2: 0.6678 - precision_2: 0.7496 - auc_2: 0.9221 - val_loss: 0.6578 - val_accuracy: 0.7237 - val_recall_2: 0.6611 - val_precision_2: 0.7476 - val_auc_2: 0.9234
# Epoch 48/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.6057 - accuracy: 0.7390 - recall_2: 0.6977 - precision_2: 0.7671 - auc_2: 0.9325 - val_loss: 0.6424 - val_accuracy: 0.7164 - val_recall_2: 0.6715 - val_precision_2: 0.7462 - val_auc_2: 0.9242
# Epoch 49/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.6301 - accuracy: 0.7294 - recall_2: 0.6803 - precision_2: 0.7602 - auc_2: 0.9273 - val_loss: 0.6121 - val_accuracy: 0.7383 - val_recall_2: 0.6986 - val_precision_2: 0.7657 - val_auc_2: 0.9320
# Epoch 50/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.5878 - accuracy: 0.7397 - recall_2: 0.7044 - precision_2: 0.7678 - auc_2: 0.9360 - val_loss: 0.6340 - val_accuracy: 0.7080 - val_recall_2: 0.6663 - val_precision_2: 0.7336 - val_auc_2: 0.9266
# Epoch 51/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.5821 - accuracy: 0.7557 - recall_2: 0.7182 - precision_2: 0.7810 - auc_2: 0.9382 - val_loss: 0.5661 - val_accuracy: 0.7477 - val_recall_2: 0.7258 - val_precision_2: 0.7742 - val_auc_2: 0.9412
# Epoch 52/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.5886 - accuracy: 0.7397 - recall_2: 0.7026 - precision_2: 0.7651 - auc_2: 0.9359 - val_loss: 0.6479 - val_accuracy: 0.7185 - val_recall_2: 0.6986 - val_precision_2: 0.7363 - val_auc_2: 0.9251
# Epoch 53/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.5534 - accuracy: 0.7609 - recall_2: 0.7269 - precision_2: 0.7872 - auc_2: 0.9428 - val_loss: 0.5950 - val_accuracy: 0.7404 - val_recall_2: 0.7185 - val_precision_2: 0.7514 - val_auc_2: 0.9355
# Epoch 54/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.5380 - accuracy: 0.7756 - recall_2: 0.7426 - precision_2: 0.7957 - auc_2: 0.9469 - val_loss: 0.6020 - val_accuracy: 0.7477 - val_recall_2: 0.7080 - val_precision_2: 0.7716 - val_auc_2: 0.9350
# Epoch 55/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.5250 - accuracy: 0.7763 - recall_2: 0.7484 - precision_2: 0.7966 - auc_2: 0.9491 - val_loss: 0.6054 - val_accuracy: 0.7435 - val_recall_2: 0.7268 - val_precision_2: 0.7626 - val_auc_2: 0.9359
# Epoch 56/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.5288 - accuracy: 0.7738 - recall_2: 0.7466 - precision_2: 0.7951 - auc_2: 0.9485 - val_loss: 0.5489 - val_accuracy: 0.7612 - val_recall_2: 0.7351 - val_precision_2: 0.7868 - val_auc_2: 0.9458
# Epoch 57/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.4956 - accuracy: 0.7933 - recall_2: 0.7689 - precision_2: 0.8126 - auc_2: 0.9549 - val_loss: 0.6145 - val_accuracy: 0.7320 - val_recall_2: 0.7080 - val_precision_2: 0.7595 - val_auc_2: 0.9319
# Epoch 58/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.4857 - accuracy: 0.7886 - recall_2: 0.7676 - precision_2: 0.8089 - auc_2: 0.9563 - val_loss: 0.5165 - val_accuracy: 0.7935 - val_recall_2: 0.7727 - val_precision_2: 0.8046 - val_auc_2: 0.9527
# Epoch 59/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.4451 - accuracy: 0.8091 - recall_2: 0.7870 - precision_2: 0.8280 - auc_2: 0.9637 - val_loss: 0.5838 - val_accuracy: 0.7424 - val_recall_2: 0.7164 - val_precision_2: 0.7676 - val_auc_2: 0.9397
# Epoch 60/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.4680 - accuracy: 0.8013 - recall_2: 0.7812 - precision_2: 0.8168 - auc_2: 0.9593 - val_loss: 0.5424 - val_accuracy: 0.7810 - val_recall_2: 0.7623 - val_precision_2: 0.7989 - val_auc_2: 0.9482
# Epoch 61/100
# 70/70 [==============================] - 92s 1s/step - loss: 0.4620 - accuracy: 0.8015 - recall_2: 0.7812 - precision_2: 0.8183 - auc_2: 0.9605 - val_loss: 0.5992 - val_accuracy: 0.7664 - val_recall_2: 0.7456 - val_precision_2: 0.7831 - val_auc_2: 0.9383
# Epoch 62/100
# 70/70 [==============================] - 91s 1s/step - loss: 0.4441 - accuracy: 0.8192 - recall_2: 0.8013 - precision_2: 0.8337 - auc_2: 0.9638 - val_loss: 0.5617 - val_accuracy: 0.7675 - val_recall_2: 0.7435 - val_precision_2: 0.7835 - val_auc_2: 0.9451
# Epoch 63/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.4286 - accuracy: 0.8196 - recall_2: 0.8073 - precision_2: 0.8374 - auc_2: 0.9659 - val_loss: 0.4881 - val_accuracy: 0.7956 - val_recall_2: 0.7758 - val_precision_2: 0.8131 - val_auc_2: 0.9580
# Epoch 64/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.3879 - accuracy: 0.8439 - recall_2: 0.8296 - precision_2: 0.8570 - auc_2: 0.9721 - val_loss: 0.4761 - val_accuracy: 0.7977 - val_recall_2: 0.7852 - val_precision_2: 0.8132 - val_auc_2: 0.9592
# Epoch 65/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.3783 - accuracy: 0.8439 - recall_2: 0.8326 - precision_2: 0.8563 - auc_2: 0.9733 - val_loss: 0.5214 - val_accuracy: 0.7779 - val_recall_2: 0.7581 - val_precision_2: 0.7876 - val_auc_2: 0.9536
# Epoch 66/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.3882 - accuracy: 0.8381 - recall_2: 0.8256 - precision_2: 0.8480 - auc_2: 0.9718 - val_loss: 0.4876 - val_accuracy: 0.8113 - val_recall_2: 0.7894 - val_precision_2: 0.8246 - val_auc_2: 0.9578
# Epoch 67/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.3905 - accuracy: 0.8397 - recall_2: 0.8267 - precision_2: 0.8517 - auc_2: 0.9717 - val_loss: 0.5326 - val_accuracy: 0.7842 - val_recall_2: 0.7727 - val_precision_2: 0.7942 - val_auc_2: 0.9540
# Epoch 68/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.3411 - accuracy: 0.8589 - recall_2: 0.8473 - precision_2: 0.8698 - auc_2: 0.9782 - val_loss: 0.4933 - val_accuracy: 0.8040 - val_recall_2: 0.7946 - val_precision_2: 0.8115 - val_auc_2: 0.9599
# Epoch 69/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.3327 - accuracy: 0.8681 - recall_2: 0.8558 - precision_2: 0.8783 - auc_2: 0.9795 - val_loss: 0.4637 - val_accuracy: 0.8008 - val_recall_2: 0.7904 - val_precision_2: 0.8151 - val_auc_2: 0.9626
# Epoch 70/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.3250 - accuracy: 0.8710 - recall_2: 0.8636 - precision_2: 0.8821 - auc_2: 0.9799 - val_loss: 0.4810 - val_accuracy: 0.8060 - val_recall_2: 0.7956 - val_precision_2: 0.8240 - val_auc_2: 0.9601
# Epoch 71/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.3241 - accuracy: 0.8701 - recall_2: 0.8602 - precision_2: 0.8801 - auc_2: 0.9800 - val_loss: 0.4553 - val_accuracy: 0.8186 - val_recall_2: 0.8133 - val_precision_2: 0.8263 - val_auc_2: 0.9644
# Epoch 72/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.2947 - accuracy: 0.8770 - recall_2: 0.8703 - precision_2: 0.8875 - auc_2: 0.9835 - val_loss: 0.3495 - val_accuracy: 0.8749 - val_recall_2: 0.8697 - val_precision_2: 0.8872 - val_auc_2: 0.9778
# Epoch 73/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.2915 - accuracy: 0.8810 - recall_2: 0.8736 - precision_2: 0.8879 - auc_2: 0.9839 - val_loss: 0.3992 - val_accuracy: 0.8478 - val_recall_2: 0.8415 - val_precision_2: 0.8603 - val_auc_2: 0.9727
# Epoch 74/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.3172 - accuracy: 0.8725 - recall_2: 0.8625 - precision_2: 0.8818 - auc_2: 0.9810 - val_loss: 0.4207 - val_accuracy: 0.8488 - val_recall_2: 0.8384 - val_precision_2: 0.8508 - val_auc_2: 0.9678
# Epoch 75/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.2703 - accuracy: 0.8955 - recall_2: 0.8899 - precision_2: 0.9006 - auc_2: 0.9858 - val_loss: 0.4417 - val_accuracy: 0.8300 - val_recall_2: 0.8133 - val_precision_2: 0.8396 - val_auc_2: 0.9667
# Epoch 76/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.2848 - accuracy: 0.8857 - recall_2: 0.8797 - precision_2: 0.8928 - auc_2: 0.9844 - val_loss: 0.4111 - val_accuracy: 0.8467 - val_recall_2: 0.8384 - val_precision_2: 0.8553 - val_auc_2: 0.9705
# Epoch 77/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.2714 - accuracy: 0.8989 - recall_2: 0.8928 - precision_2: 0.9062 - auc_2: 0.9858 - val_loss: 0.3412 - val_accuracy: 0.8561 - val_recall_2: 0.8498 - val_precision_2: 0.8670 - val_auc_2: 0.9780
# Epoch 78/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.2393 - accuracy: 0.9062 - recall_2: 0.9020 - precision_2: 0.9103 - auc_2: 0.9889 - val_loss: 0.3688 - val_accuracy: 0.8603 - val_recall_2: 0.8540 - val_precision_2: 0.8648 - val_auc_2: 0.9759
# Epoch 79/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.2427 - accuracy: 0.9022 - recall_2: 0.8964 - precision_2: 0.9094 - auc_2: 0.9885 - val_loss: 0.3399 - val_accuracy: 0.8624 - val_recall_2: 0.8592 - val_precision_2: 0.8710 - val_auc_2: 0.9791
# Epoch 80/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.2342 - accuracy: 0.9118 - recall_2: 0.9082 - precision_2: 0.9170 - auc_2: 0.9893 - val_loss: 0.4125 - val_accuracy: 0.8478 - val_recall_2: 0.8425 - val_precision_2: 0.8523 - val_auc_2: 0.9714
# Epoch 81/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.2485 - accuracy: 0.9004 - recall_2: 0.8944 - precision_2: 0.9059 - auc_2: 0.9878 - val_loss: 0.4082 - val_accuracy: 0.8582 - val_recall_2: 0.8551 - val_precision_2: 0.8613 - val_auc_2: 0.9709
# Epoch 82/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.2210 - accuracy: 0.9181 - recall_2: 0.9120 - precision_2: 0.9221 - auc_2: 0.9901 - val_loss: 0.3600 - val_accuracy: 0.8665 - val_recall_2: 0.8624 - val_precision_2: 0.8696 - val_auc_2: 0.9759
# Epoch 83/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.2151 - accuracy: 0.9152 - recall_2: 0.9102 - precision_2: 0.9218 - auc_2: 0.9907 - val_loss: 0.4016 - val_accuracy: 0.8592 - val_recall_2: 0.8582 - val_precision_2: 0.8654 - val_auc_2: 0.9724
# Epoch 84/100
# 70/70 [==============================] - 96s 1s/step - loss: 0.2229 - accuracy: 0.9154 - recall_2: 0.9116 - precision_2: 0.9196 - auc_2: 0.9900 - val_loss: 0.3340 - val_accuracy: 0.8655 - val_recall_2: 0.8571 - val_precision_2: 0.8680 - val_auc_2: 0.9797
# Epoch 85/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.2156 - accuracy: 0.9136 - recall_2: 0.9089 - precision_2: 0.9179 - auc_2: 0.9908 - val_loss: 0.3295 - val_accuracy: 0.8770 - val_recall_2: 0.8738 - val_precision_2: 0.8830 - val_auc_2: 0.9805
# Epoch 86/100
# 70/70 [==============================] - 97s 1s/step - loss: 0.2166 - accuracy: 0.9210 - recall_2: 0.9176 - precision_2: 0.9261 - auc_2: 0.9906 - val_loss: 0.3550 - val_accuracy: 0.8697 - val_recall_2: 0.8613 - val_precision_2: 0.8722 - val_auc_2: 0.9763
# Epoch 87/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.2072 - accuracy: 0.9145 - recall_2: 0.9120 - precision_2: 0.9190 - auc_2: 0.9915 - val_loss: 0.3122 - val_accuracy: 0.8822 - val_recall_2: 0.8801 - val_precision_2: 0.8875 - val_auc_2: 0.9839
# Epoch 88/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.1720 - accuracy: 0.9339 - recall_2: 0.9317 - precision_2: 0.9382 - auc_2: 0.9940 - val_loss: 0.3257 - val_accuracy: 0.8832 - val_recall_2: 0.8801 - val_precision_2: 0.8875 - val_auc_2: 0.9804
# Epoch 89/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.1779 - accuracy: 0.9317 - recall_2: 0.9297 - precision_2: 0.9345 - auc_2: 0.9931 - val_loss: 0.3334 - val_accuracy: 0.8863 - val_recall_2: 0.8822 - val_precision_2: 0.8887 - val_auc_2: 0.9785
# Epoch 90/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.1945 - accuracy: 0.9223 - recall_2: 0.9196 - precision_2: 0.9258 - auc_2: 0.9921 - val_loss: 0.2749 - val_accuracy: 0.8926 - val_recall_2: 0.8895 - val_precision_2: 0.8923 - val_auc_2: 0.9857
# Epoch 91/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.2022 - accuracy: 0.9234 - recall_2: 0.9203 - precision_2: 0.9271 - auc_2: 0.9916 - val_loss: 0.3061 - val_accuracy: 0.8916 - val_recall_2: 0.8863 - val_precision_2: 0.8947 - val_auc_2: 0.9836
# Epoch 92/100
# 70/70 [==============================] - 94s 1s/step - loss: 0.1557 - accuracy: 0.9402 - recall_2: 0.9373 - precision_2: 0.9432 - auc_2: 0.9950 - val_loss: 0.3990 - val_accuracy: 0.8634 - val_recall_2: 0.8624 - val_precision_2: 0.8669 - val_auc_2: 0.9744
# Epoch 93/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.1535 - accuracy: 0.9386 - recall_2: 0.9377 - precision_2: 0.9421 - auc_2: 0.9951 - val_loss: 0.4004 - val_accuracy: 0.8655 - val_recall_2: 0.8634 - val_precision_2: 0.8670 - val_auc_2: 0.9759
# Epoch 94/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.1587 - accuracy: 0.9408 - recall_2: 0.9395 - precision_2: 0.9433 - auc_2: 0.9946 - val_loss: 0.3026 - val_accuracy: 0.8947 - val_recall_2: 0.8905 - val_precision_2: 0.8961 - val_auc_2: 0.9830
# Epoch 95/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.1759 - accuracy: 0.9339 - recall_2: 0.9312 - precision_2: 0.9369 - auc_2: 0.9933 - val_loss: 0.3030 - val_accuracy: 0.8968 - val_recall_2: 0.8947 - val_precision_2: 0.9003 - val_auc_2: 0.9844
# Epoch 96/100
# 70/70 [==============================] - 93s 1s/step - loss: 0.2024 - accuracy: 0.9270 - recall_2: 0.9239 - precision_2: 0.9293 - auc_2: 0.9912 - val_loss: 0.3072 - val_accuracy: 0.8832 - val_recall_2: 0.8801 - val_precision_2: 0.8903 - val_auc_2: 0.9819
# Epoch 97/100
# 70/70 [==============================] - 97s 1s/step - loss: 0.1473 - accuracy: 0.9446 - recall_2: 0.9415 - precision_2: 0.9470 - auc_2: 0.9955 - val_loss: 0.4089 - val_accuracy: 0.8686 - val_recall_2: 0.8655 - val_precision_2: 0.8718 - val_auc_2: 0.9726
# Epoch 98/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.1593 - accuracy: 0.9415 - recall_2: 0.9395 - precision_2: 0.9443 - auc_2: 0.9945 - val_loss: 0.2967 - val_accuracy: 0.8978 - val_recall_2: 0.8947 - val_precision_2: 0.8994 - val_auc_2: 0.9844
# Epoch 99/100
# 70/70 [==============================] - 95s 1s/step - loss: 0.1399 - accuracy: 0.9486 - recall_2: 0.9464 - precision_2: 0.9504 - auc_2: 0.9954 - val_loss: 0.3111 - val_accuracy: 0.8863 - val_recall_2: 0.8863 - val_precision_2: 0.8901 - val_auc_2: 0.9845
# Epoch 100/100
# 70/70 [==============================] - 99s 1s/step - loss: 0.1747 - accuracy: 0.9359 - recall_2: 0.9339 - precision_2: 0.9379 - auc_2: 0.9932 - val_loss: 0.3090 - val_accuracy: 0.8978 - val_recall_2: 0.8947 - val_precision_2: 0.8994 - val_auc_2: 0.9820

# %%
metricsEval = list(model_history.history.keys())
print(metricsEval , '\n')

historyDF = pd.DataFrame(model_history.history)
historyDF.head()
historyDF.to_csv('mycsvfile.csv',index=False)
# Out:
# ['loss', 'accuracy', 'recall_2', 'precision_2', 'auc_2', 'val_loss', 'val_accuracy', 'val_recall_2', 'val_precision_2', 'val_auc_2']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axarr = plt.subplots(1, 5, figsize=(21, 8), sharex=True)

sns.set(style="ticks", font_scale=1)
sns.despine(top=True, right=True, left=False, bottom=False)

# Modify the code to create the lineplots on the same row
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[0]], ax=axarr[0], label="Validation")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[5]], ax=axarr[0], label="Training")
axarr[0].set_ylabel('Loss')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[1]], ax=axarr[1], label="Validation")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[6]], ax=axarr[1], label="Training")
axarr[1].set_ylabel('Accuracy')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[2]], ax=axarr[2], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[7]], ax=axarr[2], label="Validation")
axarr[2].set_ylabel('Precision')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[3]], ax=axarr[3], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[8]], ax=axarr[3], label="Validation")
axarr[3].set_ylabel('Recall')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[4]], ax=axarr[4], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[9]], ax=axarr[4], label="Validation")
axarr[4].set_ylabel('AUC')

# Modify the titles and labels as needed
axarr[0].set_title('Loss', fontsize=17)
axarr[1].set_title('Accuracy', fontsize=17)
axarr[2].set_title('Precision', fontsize=17)
axarr[3].set_title('Recall', fontsize=17)
axarr[4].set_title('AUC', fontsize=17)

for ax in axarr:
    ax.set_xlabel('Epochs')

plt.suptitle('Training and Validation Performance Plots', fontsize=19, weight='bold')
fig.tight_layout(pad=3.0)
plt.savefig("trainingandval.png", dpi=1080)
plt.show()

# %%
# Assuming you have test_data and test_labels for your test set
test_metrics = model.evaluate(test_data)

test_accuracy = test_metrics[1]
test_precision = test_metrics[3]
test_recall = test_metrics[2]
test_auc = test_metrics[4]

# Calculate F1 score
test_f1_score = 2 * (test_precision * test_recall) / (test_precision + test_recall)

print("Test Accuracy:", test_accuracy)
print("Test Precision:", test_precision)
print("Test Recall:", test_recall)
print("Test AUC:", test_auc)
print("Test F1 Score:", test_f1_score)
# Out:
# 16/16 [==============================] - 4s 263ms/step - loss: 0.2675 - accuracy: 0.8981 - recall_2: 0.8960 - precision_2: 0.9007 - auc_2: 0.9867
# Test Accuracy: 0.8981289267539978
# Test Precision: 0.9007314443588257
# Test Recall: 0.8960499167442322
# Test AUC: 0.9867472648620605
# Test F1 Score: 0.8983845816734793

# %%
import visualkeras
visualkeras.layered_view(model, legend=True) # without custom font
from PIL import ImageFont

visualkeras.layered_view(model, legend=True, ) # selected font
# Out:
# <PIL.Image.Image image mode=RGBA size=1603x1231>
