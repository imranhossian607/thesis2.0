# %% [markdown]
# <a href="https://colab.research.google.com/github/imranhossian607/thesis2.0/blob/main/dropout_0_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import warnings

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow import keras
import tensorflow
import scipy
print("Num GPUs Available: ", len(tensorflow.config.list_physical_devices('GPU')))


# Set the seed value for experiment reproduci.bility.
seed = 1842
tensorflow.random.set_seed(seed)
np.random.seed(seed)
# Turn off warnings for cleaner looking notebook
warnings.simplefilter('ignore')
# Out:
# Num GPUs Available:  1

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Split the dataset into train, validation, and test sets
input_folder = '/content/drive/MyDrive/Dataset'
output_folder = 'output'

splitfolders.ratio(input_folder, output=output_folder, seed=1345, ratio=(0.7, 0.15, 0.15))

# Define data augmentation parameters
WIDTH,HEIGHT=224,224

train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.2,          # Zoom in/out by a maximum of 20%
                                   horizontal_flip=True,)

valid_datagen = ImageDataGenerator(rescale = 1./255)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# Define the directories for your training, validation, and test sets
train_dir = os.path.join(output_folder, 'train')
valid_dir = os.path.join(output_folder, 'val')
test_dir = os.path.join(output_folder, 'test')

# Apply data augmentation to the training dataset
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size = (WIDTH,HEIGHT),
    color_mode = "rgb",
    batch_size = 64,
    interpolation = "bicubic" ,
    shuffle = True ,
    class_mode='categorical'  # Change to appropriate mode for your dataset
)


# No augmentation for validation and test datasets
valid_data = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=(WIDTH,HEIGHT),   # Adjust the target size as needed
    color_mode = "rgb",
    batch_size = 64,
    interpolation = "bicubic" ,
    shuffle = True ,
    class_mode='categorical'  # Change to appropriate mode for your dataset
)

test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=(WIDTH,HEIGHT),   # Adjust the target size as needed
    color_mode = "rgb",
    batch_size = 64,
    interpolation = "bicubic" ,
    shuffle = True ,
    class_mode='categorical'  # Change to appropriate mode for your dataset
)
# Out:
# Copying files: 6400 files [03:19, 32.16 files/s]
# Found 4479 images belonging to 4 classes.
# Found 959 images belonging to 4 classes.
# Found 962 images belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

batch_1_img = train_data[0]
plt.figure(figsize=(12, 4))  # Adjust the figure size as needed

for i in range(4):
    img = batch_1_img[0][i]
    lab = batch_1_img[1][i]

    # Create a subplot for each image
    plt.subplot(1, 4, i + 1)
    plt.imshow(img)
    plt.title(f'Class: {lab}')  # Set the title to display the class label
    plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt

batch_1_img = test_data[0]
plt.figure(figsize=(12, 4))  # Adjust the figure size as needed

for i in range(4):
    img = batch_1_img[0][i]
    lab = batch_1_img[1][i]

    # Create a subplot for each image
    plt.subplot(1, 4, i + 1)
    plt.imshow(img)
    plt.title(f'Class: {lab}')  # Set the title to display the class label
    plt.axis('off')

plt.show()

# %% [markdown]
# #CNN

# %%
import tensorflow as tf
from tensorflow import keras

input_shape = (WIDTH, HEIGHT, 3)

# Define your CNN model
model = keras.models.Sequential()

model.add(keras.layers.Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu', kernel_initializer="he_normal", input_shape=input_shape))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(keras.layers.Dropout(0.30))

model.add(keras.layers.Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu', kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(keras.layers.Dropout(0.30))

model.add(keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu', kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))

model.add(keras.layers.Dropout(0.30))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128, activation="relu", kernel_initializer="he_normal"))
model.add(keras.layers.Dense(64, activation="relu"))
model.add(keras.layers.Dense(4, activation="softmax"))

# Print model summary
model.summary()

# Compile the model
model.compile(
    optimizer='adam',
    loss=tf.losses.CategoricalCrossentropy(),
    metrics=["accuracy", tf.metrics.Recall(), tf.metrics.Precision(), tf.metrics.AUC()]
)

# Early stopping callback
callback = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# Train the model
model_history = model.fit(train_data, epochs=100, validation_data=valid_data, callbacks=[callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 16)      0
#  D)
#
#  dropout (Dropout)           (None, 112, 112, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 56, 56, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 28, 28, 64)        0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 128)               6422656
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 6454756 (24.62 MB)
# Trainable params: 6454756 (24.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 70/70 [==============================] - 94s 980ms/step - loss: 2.7585 - accuracy: 0.4604 - recall: 0.2675 - precision: 0.4687 - auc: 0.7267 - val_loss: 1.2759 - val_accuracy: 0.5005 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.7762
# Epoch 2/100
# 70/70 [==============================] - 70s 1s/step - loss: 1.0252 - accuracy: 0.4997 - recall: 0.2844 - precision: 0.5698 - auc: 0.7937 - val_loss: 1.2232 - val_accuracy: 0.4995 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.8001
# Epoch 3/100
# 70/70 [==============================] - 65s 922ms/step - loss: 1.0201 - accuracy: 0.5048 - recall: 0.2849 - precision: 0.5753 - auc: 0.7962 - val_loss: 1.2000 - val_accuracy: 0.5036 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.8009
# Epoch 4/100
# 70/70 [==============================] - 65s 927ms/step - loss: 0.9872 - accuracy: 0.5124 - recall: 0.3505 - precision: 0.6045 - auc: 0.8109 - val_loss: 1.1769 - val_accuracy: 0.5224 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.8156
# Epoch 5/100
# 70/70 [==============================] - 66s 931ms/step - loss: 0.9512 - accuracy: 0.5410 - recall: 0.3452 - precision: 0.6442 - auc: 0.8253 - val_loss: 1.1386 - val_accuracy: 0.5381 - val_recall: 0.0146 - val_precision: 0.9333 - val_auc: 0.8212
# Epoch 6/100
# 70/70 [==============================] - 65s 936ms/step - loss: 0.9476 - accuracy: 0.5441 - recall: 0.3628 - precision: 0.6474 - auc: 0.8265 - val_loss: 1.0832 - val_accuracy: 0.5297 - val_recall: 0.1449 - val_precision: 0.8634 - val_auc: 0.8246
# Epoch 7/100
# 70/70 [==============================] - 68s 970ms/step - loss: 0.9361 - accuracy: 0.5483 - recall: 0.3608 - precision: 0.6367 - auc: 0.8308 - val_loss: 1.0621 - val_accuracy: 0.5391 - val_recall: 0.1981 - val_precision: 0.8051 - val_auc: 0.8299
# Epoch 8/100
# 70/70 [==============================] - 65s 933ms/step - loss: 0.9244 - accuracy: 0.5535 - recall: 0.3666 - precision: 0.6579 - auc: 0.8345 - val_loss: 1.0411 - val_accuracy: 0.5422 - val_recall: 0.2106 - val_precision: 0.8145 - val_auc: 0.8330
# Epoch 9/100
# 70/70 [==============================] - 71s 1s/step - loss: 0.9122 - accuracy: 0.5646 - recall: 0.3833 - precision: 0.6718 - auc: 0.8395 - val_loss: 1.0689 - val_accuracy: 0.5370 - val_recall: 0.1147 - val_precision: 0.9565 - val_auc: 0.8235
# Epoch 10/100
# 70/70 [==============================] - 65s 935ms/step - loss: 0.9026 - accuracy: 0.5644 - recall: 0.3818 - precision: 0.6677 - auc: 0.8439 - val_loss: 1.0239 - val_accuracy: 0.5589 - val_recall: 0.1846 - val_precision: 0.8592 - val_auc: 0.8378
# Epoch 11/100
# 70/70 [==============================] - 65s 933ms/step - loss: 0.8971 - accuracy: 0.5646 - recall: 0.3670 - precision: 0.6705 - auc: 0.8431 - val_loss: 1.0110 - val_accuracy: 0.5370 - val_recall: 0.1752 - val_precision: 0.8615 - val_auc: 0.8288
# Epoch 12/100
# 70/70 [==============================] - 67s 956ms/step - loss: 0.8836 - accuracy: 0.5658 - recall: 0.3905 - precision: 0.6719 - auc: 0.8484 - val_loss: 0.9642 - val_accuracy: 0.5558 - val_recall: 0.2033 - val_precision: 0.8478 - val_auc: 0.8392
# Epoch 13/100
# 70/70 [==============================] - 65s 928ms/step - loss: 0.8887 - accuracy: 0.5653 - recall: 0.3833 - precision: 0.6779 - auc: 0.8458 - val_loss: 0.9596 - val_accuracy: 0.5683 - val_recall: 0.2138 - val_precision: 0.8436 - val_auc: 0.8475
# Epoch 14/100
# 70/70 [==============================] - 65s 927ms/step - loss: 0.8714 - accuracy: 0.5778 - recall: 0.3900 - precision: 0.6927 - auc: 0.8534 - val_loss: 0.9699 - val_accuracy: 0.5683 - val_recall: 0.2013 - val_precision: 0.8465 - val_auc: 0.8517
# Epoch 15/100
# 70/70 [==============================] - 66s 948ms/step - loss: 0.8653 - accuracy: 0.5800 - recall: 0.3994 - precision: 0.6813 - auc: 0.8545 - val_loss: 0.9547 - val_accuracy: 0.5965 - val_recall: 0.1960 - val_precision: 0.8664 - val_auc: 0.8594
# Epoch 16/100
# 70/70 [==============================] - 65s 928ms/step - loss: 0.8543 - accuracy: 0.5874 - recall: 0.4229 - precision: 0.6902 - auc: 0.8582 - val_loss: 0.9093 - val_accuracy: 0.5725 - val_recall: 0.2701 - val_precision: 0.7731 - val_auc: 0.8514
# Epoch 17/100
# 70/70 [==============================] - 67s 964ms/step - loss: 0.8579 - accuracy: 0.5825 - recall: 0.4168 - precision: 0.6811 - auc: 0.8577 - val_loss: 0.9491 - val_accuracy: 0.5860 - val_recall: 0.2127 - val_precision: 0.8430 - val_auc: 0.8580
# Epoch 18/100
# 70/70 [==============================] - 67s 964ms/step - loss: 0.8391 - accuracy: 0.5950 - recall: 0.4338 - precision: 0.6907 - auc: 0.8635 - val_loss: 0.8889 - val_accuracy: 0.5965 - val_recall: 0.2920 - val_precision: 0.7487 - val_auc: 0.8614
# Epoch 19/100
# 70/70 [==============================] - 65s 925ms/step - loss: 0.8245 - accuracy: 0.6075 - recall: 0.4546 - precision: 0.6864 - auc: 0.8693 - val_loss: 0.8514 - val_accuracy: 0.6194 - val_recall: 0.2941 - val_precision: 0.8127 - val_auc: 0.8770
# Epoch 20/100
# 70/70 [==============================] - 67s 964ms/step - loss: 0.8231 - accuracy: 0.6153 - recall: 0.4807 - precision: 0.6930 - auc: 0.8704 - val_loss: 0.8292 - val_accuracy: 0.6058 - val_recall: 0.3379 - val_precision: 0.8161 - val_auc: 0.8757
# Epoch 21/100
# 70/70 [==============================] - 65s 932ms/step - loss: 0.7983 - accuracy: 0.6242 - recall: 0.5046 - precision: 0.6997 - auc: 0.8788 - val_loss: 0.8379 - val_accuracy: 0.6121 - val_recall: 0.3462 - val_precision: 0.7563 - val_auc: 0.8734
# Epoch 22/100
# 70/70 [==============================] - 65s 934ms/step - loss: 0.7884 - accuracy: 0.6301 - recall: 0.5046 - precision: 0.6952 - auc: 0.8809 - val_loss: 0.8331 - val_accuracy: 0.6152 - val_recall: 0.3379 - val_precision: 0.8161 - val_auc: 0.8830
# Epoch 23/100
# 70/70 [==============================] - 68s 969ms/step - loss: 0.7833 - accuracy: 0.6292 - recall: 0.5153 - precision: 0.7013 - auc: 0.8824 - val_loss: 0.8187 - val_accuracy: 0.6538 - val_recall: 0.3493 - val_precision: 0.8481 - val_auc: 0.8907
# Epoch 24/100
# 70/70 [==============================] - 65s 936ms/step - loss: 0.7729 - accuracy: 0.6450 - recall: 0.5323 - precision: 0.7072 - auc: 0.8869 - val_loss: 0.8029 - val_accuracy: 0.6632 - val_recall: 0.3900 - val_precision: 0.7857 - val_auc: 0.8925
# Epoch 25/100
# 70/70 [==============================] - 71s 1s/step - loss: 0.7672 - accuracy: 0.6428 - recall: 0.5363 - precision: 0.7138 - auc: 0.8886 - val_loss: 0.7733 - val_accuracy: 0.6590 - val_recall: 0.4453 - val_precision: 0.8026 - val_auc: 0.8972
# Epoch 26/100
# 70/70 [==============================] - 66s 937ms/step - loss: 0.7391 - accuracy: 0.6600 - recall: 0.5606 - precision: 0.7213 - auc: 0.8970 - val_loss: 0.7428 - val_accuracy: 0.6830 - val_recall: 0.4911 - val_precision: 0.7889 - val_auc: 0.9052
# Epoch 27/100
# 70/70 [==============================] - 65s 932ms/step - loss: 0.7427 - accuracy: 0.6542 - recall: 0.5606 - precision: 0.7156 - auc: 0.8947 - val_loss: 0.7572 - val_accuracy: 0.6382 - val_recall: 0.4828 - val_precision: 0.7303 - val_auc: 0.8919
# Epoch 28/100
# 70/70 [==============================] - 67s 962ms/step - loss: 0.7136 - accuracy: 0.6745 - recall: 0.5876 - precision: 0.7170 - auc: 0.9033 - val_loss: 0.7248 - val_accuracy: 0.6517 - val_recall: 0.5182 - val_precision: 0.7474 - val_auc: 0.9048
# Epoch 29/100
# 70/70 [==============================] - 65s 927ms/step - loss: 0.6876 - accuracy: 0.6906 - recall: 0.6124 - precision: 0.7374 - auc: 0.9112 - val_loss: 0.7100 - val_accuracy: 0.6788 - val_recall: 0.5495 - val_precision: 0.7350 - val_auc: 0.9058
# Epoch 30/100
# 70/70 [==============================] - 66s 938ms/step - loss: 0.6894 - accuracy: 0.6856 - recall: 0.6037 - precision: 0.7314 - auc: 0.9101 - val_loss: 0.6764 - val_accuracy: 0.7059 - val_recall: 0.5683 - val_precision: 0.7933 - val_auc: 0.9193
# Epoch 31/100
# 70/70 [==============================] - 65s 936ms/step - loss: 0.6756 - accuracy: 0.6984 - recall: 0.6207 - precision: 0.7429 - auc: 0.9147 - val_loss: 0.6835 - val_accuracy: 0.7007 - val_recall: 0.5641 - val_precision: 0.7663 - val_auc: 0.9176
# Epoch 32/100
# 70/70 [==============================] - 69s 983ms/step - loss: 0.6570 - accuracy: 0.7066 - recall: 0.6412 - precision: 0.7456 - auc: 0.9195 - val_loss: 0.6325 - val_accuracy: 0.7351 - val_recall: 0.6069 - val_precision: 0.8117 - val_auc: 0.9326
# Epoch 33/100
# 70/70 [==============================] - 65s 931ms/step - loss: 0.6581 - accuracy: 0.6952 - recall: 0.6301 - precision: 0.7432 - auc: 0.9187 - val_loss: 0.6480 - val_accuracy: 0.7247 - val_recall: 0.5933 - val_precision: 0.8025 - val_auc: 0.9311
# Epoch 34/100
# 70/70 [==============================] - 64s 921ms/step - loss: 0.6285 - accuracy: 0.7261 - recall: 0.6649 - precision: 0.7661 - auc: 0.9268 - val_loss: 0.6430 - val_accuracy: 0.6903 - val_recall: 0.6048 - val_precision: 0.7436 - val_auc: 0.9210
# Epoch 35/100
# 70/70 [==============================] - 65s 923ms/step - loss: 0.6190 - accuracy: 0.7236 - recall: 0.6647 - precision: 0.7571 - auc: 0.9278 - val_loss: 0.6099 - val_accuracy: 0.7466 - val_recall: 0.6340 - val_precision: 0.8161 - val_auc: 0.9396
# Epoch 36/100
# 70/70 [==============================] - 65s 930ms/step - loss: 0.6092 - accuracy: 0.7281 - recall: 0.6714 - precision: 0.7651 - auc: 0.9305 - val_loss: 0.6002 - val_accuracy: 0.7310 - val_recall: 0.6611 - val_precision: 0.7847 - val_auc: 0.9348
# Epoch 37/100
# 70/70 [==============================] - 66s 934ms/step - loss: 0.5897 - accuracy: 0.7450 - recall: 0.6957 - precision: 0.7800 - auc: 0.9359 - val_loss: 0.5732 - val_accuracy: 0.7581 - val_recall: 0.6726 - val_precision: 0.8103 - val_auc: 0.9434
# Epoch 38/100
# 70/70 [==============================] - 64s 921ms/step - loss: 0.5944 - accuracy: 0.7363 - recall: 0.6890 - precision: 0.7725 - auc: 0.9341 - val_loss: 0.5600 - val_accuracy: 0.7560 - val_recall: 0.6642 - val_precision: 0.8084 - val_auc: 0.9467
# Epoch 39/100
# 70/70 [==============================] - 67s 965ms/step - loss: 0.5711 - accuracy: 0.7466 - recall: 0.7064 - precision: 0.7812 - auc: 0.9393 - val_loss: 0.5957 - val_accuracy: 0.7122 - val_recall: 0.6486 - val_precision: 0.7458 - val_auc: 0.9317
# Epoch 40/100
# 70/70 [==============================] - 67s 949ms/step - loss: 0.5619 - accuracy: 0.7562 - recall: 0.7158 - precision: 0.7893 - auc: 0.9413 - val_loss: 0.5486 - val_accuracy: 0.7946 - val_recall: 0.6955 - val_precision: 0.8286 - val_auc: 0.9524
# Epoch 41/100
# 70/70 [==============================] - 65s 937ms/step - loss: 0.5509 - accuracy: 0.7600 - recall: 0.7194 - precision: 0.7870 - auc: 0.9436 - val_loss: 0.5299 - val_accuracy: 0.7987 - val_recall: 0.7331 - val_precision: 0.8242 - val_auc: 0.9529
# Epoch 42/100
# 70/70 [==============================] - 67s 948ms/step - loss: 0.5209 - accuracy: 0.7749 - recall: 0.7417 - precision: 0.8011 - auc: 0.9495 - val_loss: 0.5024 - val_accuracy: 0.7831 - val_recall: 0.7268 - val_precision: 0.8171 - val_auc: 0.9558
# Epoch 43/100
# 70/70 [==============================] - 65s 925ms/step - loss: 0.5136 - accuracy: 0.7756 - recall: 0.7430 - precision: 0.7988 - auc: 0.9511 - val_loss: 0.5073 - val_accuracy: 0.8029 - val_recall: 0.7456 - val_precision: 0.8412 - val_auc: 0.9586
# Epoch 44/100
# 70/70 [==============================] - 66s 941ms/step - loss: 0.5079 - accuracy: 0.7783 - recall: 0.7479 - precision: 0.8043 - auc: 0.9519 - val_loss: 0.4810 - val_accuracy: 0.8019 - val_recall: 0.7643 - val_precision: 0.8282 - val_auc: 0.9576
# Epoch 45/100
# 70/70 [==============================] - 66s 930ms/step - loss: 0.4950 - accuracy: 0.7917 - recall: 0.7618 - precision: 0.8141 - auc: 0.9549 - val_loss: 0.4577 - val_accuracy: 0.8165 - val_recall: 0.7789 - val_precision: 0.8318 - val_auc: 0.9636
# Epoch 46/100
# 70/70 [==============================] - 65s 925ms/step - loss: 0.4737 - accuracy: 0.7950 - recall: 0.7669 - precision: 0.8179 - auc: 0.9580 - val_loss: 0.4552 - val_accuracy: 0.7956 - val_recall: 0.7623 - val_precision: 0.8204 - val_auc: 0.9623
# Epoch 47/100
# 70/70 [==============================] - 70s 1s/step - loss: 0.4705 - accuracy: 0.7964 - recall: 0.7700 - precision: 0.8187 - auc: 0.9592 - val_loss: 0.4123 - val_accuracy: 0.8446 - val_recall: 0.8092 - val_precision: 0.8719 - val_auc: 0.9730
# Epoch 48/100
# 70/70 [==============================] - 67s 950ms/step - loss: 0.4641 - accuracy: 0.8033 - recall: 0.7781 - precision: 0.8196 - auc: 0.9599 - val_loss: 0.3992 - val_accuracy: 0.8384 - val_recall: 0.8050 - val_precision: 0.8655 - val_auc: 0.9733
# Epoch 49/100
# 70/70 [==============================] - 67s 953ms/step - loss: 0.4438 - accuracy: 0.8136 - recall: 0.7917 - precision: 0.8303 - auc: 0.9633 - val_loss: 0.4555 - val_accuracy: 0.8071 - val_recall: 0.7862 - val_precision: 0.8341 - val_auc: 0.9620
# Epoch 50/100
# 70/70 [==============================] - 68s 975ms/step - loss: 0.4338 - accuracy: 0.8154 - recall: 0.7942 - precision: 0.8371 - auc: 0.9652 - val_loss: 0.4154 - val_accuracy: 0.8290 - val_recall: 0.7967 - val_precision: 0.8442 - val_auc: 0.9683
# Epoch 51/100
# 70/70 [==============================] - 66s 939ms/step - loss: 0.4251 - accuracy: 0.8241 - recall: 0.8035 - precision: 0.8393 - auc: 0.9667 - val_loss: 0.4163 - val_accuracy: 0.8373 - val_recall: 0.8071 - val_precision: 0.8478 - val_auc: 0.9682
# Epoch 52/100
# 70/70 [==============================] - 69s 987ms/step - loss: 0.4053 - accuracy: 0.8283 - recall: 0.8111 - precision: 0.8431 - auc: 0.9695 - val_loss: 0.3605 - val_accuracy: 0.8686 - val_recall: 0.8551 - val_precision: 0.8817 - val_auc: 0.9769
# Epoch 53/100
# 70/70 [==============================] - 65s 935ms/step - loss: 0.4058 - accuracy: 0.8308 - recall: 0.8116 - precision: 0.8436 - auc: 0.9695 - val_loss: 0.3627 - val_accuracy: 0.8655 - val_recall: 0.8498 - val_precision: 0.8773 - val_auc: 0.9792
# Epoch 54/100
# 70/70 [==============================] - 65s 932ms/step - loss: 0.3846 - accuracy: 0.8392 - recall: 0.8212 - precision: 0.8524 - auc: 0.9724 - val_loss: 0.3648 - val_accuracy: 0.8540 - val_recall: 0.8373 - val_precision: 0.8728 - val_auc: 0.9768
# Epoch 55/100
# 70/70 [==============================] - 70s 1s/step - loss: 0.3754 - accuracy: 0.8424 - recall: 0.8276 - precision: 0.8553 - auc: 0.9739 - val_loss: 0.3306 - val_accuracy: 0.8665 - val_recall: 0.8457 - val_precision: 0.8796 - val_auc: 0.9813
# Epoch 56/100
# 70/70 [==============================] - 65s 930ms/step - loss: 0.3645 - accuracy: 0.8524 - recall: 0.8379 - precision: 0.8655 - auc: 0.9753 - val_loss: 0.3743 - val_accuracy: 0.8436 - val_recall: 0.8186 - val_precision: 0.8551 - val_auc: 0.9743
# Epoch 57/100
# 70/70 [==============================] - 69s 984ms/step - loss: 0.3719 - accuracy: 0.8430 - recall: 0.8267 - precision: 0.8534 - auc: 0.9741 - val_loss: 0.3517 - val_accuracy: 0.8488 - val_recall: 0.8311 - val_precision: 0.8616 - val_auc: 0.9788
# Epoch 58/100
# 70/70 [==============================] - 66s 941ms/step - loss: 0.3561 - accuracy: 0.8526 - recall: 0.8401 - precision: 0.8659 - auc: 0.9763 - val_loss: 0.3443 - val_accuracy: 0.8571 - val_recall: 0.8425 - val_precision: 0.8679 - val_auc: 0.9784
# Epoch 59/100
# 70/70 [==============================] - 65s 934ms/step - loss: 0.3558 - accuracy: 0.8547 - recall: 0.8446 - precision: 0.8657 - auc: 0.9763 - val_loss: 0.3189 - val_accuracy: 0.8749 - val_recall: 0.8530 - val_precision: 0.8882 - val_auc: 0.9818
# Epoch 60/100
# 70/70 [==============================] - 68s 971ms/step - loss: 0.3490 - accuracy: 0.8616 - recall: 0.8477 - precision: 0.8727 - auc: 0.9770 - val_loss: 0.2746 - val_accuracy: 0.9030 - val_recall: 0.8916 - val_precision: 0.9164 - val_auc: 0.9870
# Epoch 61/100
# 70/70 [==============================] - 65s 927ms/step - loss: 0.3085 - accuracy: 0.8754 - recall: 0.8674 - precision: 0.8864 - auc: 0.9822 - val_loss: 0.2996 - val_accuracy: 0.8999 - val_recall: 0.8822 - val_precision: 0.9107 - val_auc: 0.9853
# Epoch 62/100
# 70/70 [==============================] - 69s 992ms/step - loss: 0.3035 - accuracy: 0.8797 - recall: 0.8676 - precision: 0.8892 - auc: 0.9827 - val_loss: 0.2969 - val_accuracy: 0.8916 - val_recall: 0.8790 - val_precision: 0.8987 - val_auc: 0.9838
# Epoch 63/100
# 70/70 [==============================] - 66s 939ms/step - loss: 0.2891 - accuracy: 0.8928 - recall: 0.8835 - precision: 0.8985 - auc: 0.9838 - val_loss: 0.2592 - val_accuracy: 0.8916 - val_recall: 0.8874 - val_precision: 0.8986 - val_auc: 0.9879
# Epoch 64/100
# 70/70 [==============================] - 65s 925ms/step - loss: 0.3072 - accuracy: 0.8705 - recall: 0.8629 - precision: 0.8812 - auc: 0.9822 - val_loss: 0.2648 - val_accuracy: 0.9020 - val_recall: 0.8957 - val_precision: 0.9080 - val_auc: 0.9874
# Epoch 65/100
# 70/70 [==============================] - 65s 928ms/step - loss: 0.2909 - accuracy: 0.8837 - recall: 0.8747 - precision: 0.8917 - auc: 0.9840 - val_loss: 0.2346 - val_accuracy: 0.9155 - val_recall: 0.9062 - val_precision: 0.9225 - val_auc: 0.9906
# Epoch 66/100
# 70/70 [==============================] - 68s 971ms/step - loss: 0.2755 - accuracy: 0.8913 - recall: 0.8830 - precision: 0.8983 - auc: 0.9852 - val_loss: 0.2369 - val_accuracy: 0.9155 - val_recall: 0.9082 - val_precision: 0.9266 - val_auc: 0.9902
# Epoch 67/100
# 70/70 [==============================] - 65s 929ms/step - loss: 0.2580 - accuracy: 0.8964 - recall: 0.8897 - precision: 0.9047 - auc: 0.9873 - val_loss: 0.2561 - val_accuracy: 0.8968 - val_recall: 0.8822 - val_precision: 0.9038 - val_auc: 0.9880
# Epoch 68/100
# 70/70 [==============================] - 65s 928ms/step - loss: 0.2594 - accuracy: 0.8975 - recall: 0.8915 - precision: 0.9028 - auc: 0.9873 - val_loss: 0.2740 - val_accuracy: 0.8978 - val_recall: 0.8905 - val_precision: 0.9037 - val_auc: 0.9860
# Epoch 69/100
# 70/70 [==============================] - 67s 964ms/step - loss: 0.2450 - accuracy: 0.9013 - recall: 0.8951 - precision: 0.9091 - auc: 0.9883 - val_loss: 0.2362 - val_accuracy: 0.9228 - val_recall: 0.9166 - val_precision: 0.9243 - val_auc: 0.9891
# Epoch 70/100
# 70/70 [==============================] - 69s 984ms/step - loss: 0.2580 - accuracy: 0.9038 - recall: 0.8971 - precision: 0.9090 - auc: 0.9869 - val_loss: 0.2187 - val_accuracy: 0.9176 - val_recall: 0.9145 - val_precision: 0.9271 - val_auc: 0.9915
# Epoch 71/100
# 70/70 [==============================] - 65s 936ms/step - loss: 0.2702 - accuracy: 0.8937 - recall: 0.8859 - precision: 0.9002 - auc: 0.9857 - val_loss: 0.2043 - val_accuracy: 0.9312 - val_recall: 0.9197 - val_precision: 0.9383 - val_auc: 0.9928
# Epoch 72/100
# 70/70 [==============================] - 66s 939ms/step - loss: 0.2161 - accuracy: 0.9183 - recall: 0.9114 - precision: 0.9227 - auc: 0.9908 - val_loss: 0.2456 - val_accuracy: 0.8936 - val_recall: 0.8853 - val_precision: 0.8984 - val_auc: 0.9878
# Epoch 73/100
# 70/70 [==============================] - 66s 951ms/step - loss: 0.2442 - accuracy: 0.9049 - recall: 0.8982 - precision: 0.9110 - auc: 0.9884 - val_loss: 0.2238 - val_accuracy: 0.9239 - val_recall: 0.9187 - val_precision: 0.9283 - val_auc: 0.9907
# Epoch 74/100
# 70/70 [==============================] - 65s 934ms/step - loss: 0.2327 - accuracy: 0.9082 - recall: 0.9031 - precision: 0.9141 - auc: 0.9897 - val_loss: 0.2048 - val_accuracy: 0.9208 - val_recall: 0.9187 - val_precision: 0.9283 - val_auc: 0.9924
# Epoch 75/100
# 70/70 [==============================] - 65s 925ms/step - loss: 0.2249 - accuracy: 0.9105 - recall: 0.9067 - precision: 0.9155 - auc: 0.9901 - val_loss: 0.1950 - val_accuracy: 0.9353 - val_recall: 0.9312 - val_precision: 0.9430 - val_auc: 0.9930
# Epoch 76/100
# 70/70 [==============================] - 65s 927ms/step - loss: 0.2219 - accuracy: 0.9114 - recall: 0.9087 - precision: 0.9158 - auc: 0.9903 - val_loss: 0.2044 - val_accuracy: 0.9228 - val_recall: 0.9228 - val_precision: 0.9286 - val_auc: 0.9920
# Epoch 77/100
# 70/70 [==============================] - 66s 940ms/step - loss: 0.2302 - accuracy: 0.9091 - recall: 0.9047 - precision: 0.9138 - auc: 0.9896 - val_loss: 0.1737 - val_accuracy: 0.9437 - val_recall: 0.9364 - val_precision: 0.9513 - val_auc: 0.9953
# Epoch 78/100
# 70/70 [==============================] - 65s 928ms/step - loss: 0.2116 - accuracy: 0.9187 - recall: 0.9132 - precision: 0.9245 - auc: 0.9912 - val_loss: 0.2049 - val_accuracy: 0.9270 - val_recall: 0.9249 - val_precision: 0.9317 - val_auc: 0.9914
# Epoch 79/100
# 70/70 [==============================] - 65s 925ms/step - loss: 0.2062 - accuracy: 0.9230 - recall: 0.9178 - precision: 0.9286 - auc: 0.9917 - val_loss: 0.1731 - val_accuracy: 0.9416 - val_recall: 0.9353 - val_precision: 0.9442 - val_auc: 0.9933
# Epoch 80/100
# 70/70 [==============================] - 69s 987ms/step - loss: 0.2074 - accuracy: 0.9163 - recall: 0.9136 - precision: 0.9210 - auc: 0.9914 - val_loss: 0.2473 - val_accuracy: 0.8968 - val_recall: 0.8905 - val_precision: 0.9018 - val_auc: 0.9882
# Epoch 81/100
# 70/70 [==============================] - 66s 929ms/step - loss: 0.1961 - accuracy: 0.9279 - recall: 0.9252 - precision: 0.9314 - auc: 0.9919 - val_loss: 0.1472 - val_accuracy: 0.9479 - val_recall: 0.9458 - val_precision: 0.9537 - val_auc: 0.9958
# Epoch 82/100
# 70/70 [==============================] - 67s 964ms/step - loss: 0.1826 - accuracy: 0.9297 - recall: 0.9254 - precision: 0.9346 - auc: 0.9935 - val_loss: 0.1519 - val_accuracy: 0.9468 - val_recall: 0.9416 - val_precision: 0.9495 - val_auc: 0.9950
# Epoch 83/100
# 70/70 [==============================] - 65s 929ms/step - loss: 0.1934 - accuracy: 0.9250 - recall: 0.9196 - precision: 0.9285 - auc: 0.9922 - val_loss: 0.1684 - val_accuracy: 0.9364 - val_recall: 0.9353 - val_precision: 0.9412 - val_auc: 0.9940
# Epoch 84/100
# 70/70 [==============================] - 64s 923ms/step - loss: 0.1686 - accuracy: 0.9375 - recall: 0.9344 - precision: 0.9407 - auc: 0.9942 - val_loss: 0.1500 - val_accuracy: 0.9437 - val_recall: 0.9406 - val_precision: 0.9465 - val_auc: 0.9957
# Epoch 85/100
# 70/70 [==============================] - 68s 973ms/step - loss: 0.1745 - accuracy: 0.9317 - recall: 0.9301 - precision: 0.9339 - auc: 0.9940 - val_loss: 0.1518 - val_accuracy: 0.9447 - val_recall: 0.9426 - val_precision: 0.9466 - val_auc: 0.9952
# Epoch 86/100
# 70/70 [==============================] - 65s 923ms/step - loss: 0.1777 - accuracy: 0.9359 - recall: 0.9330 - precision: 0.9380 - auc: 0.9936 - val_loss: 0.1490 - val_accuracy: 0.9458 - val_recall: 0.9406 - val_precision: 0.9485 - val_auc: 0.9960
# Epoch 87/100
# 70/70 [==============================] - 64s 923ms/step - loss: 0.1565 - accuracy: 0.9393 - recall: 0.9355 - precision: 0.9426 - auc: 0.9949 - val_loss: 0.1356 - val_accuracy: 0.9531 - val_recall: 0.9489 - val_precision: 0.9569 - val_auc: 0.9959
# Epoch 88/100
# 70/70 [==============================] - 64s 922ms/step - loss: 0.1755 - accuracy: 0.9324 - recall: 0.9303 - precision: 0.9358 - auc: 0.9938 - val_loss: 0.1238 - val_accuracy: 0.9562 - val_recall: 0.9541 - val_precision: 0.9621 - val_auc: 0.9972
# Epoch 89/100
# 70/70 [==============================] - 67s 962ms/step - loss: 0.1656 - accuracy: 0.9346 - recall: 0.9308 - precision: 0.9377 - auc: 0.9941 - val_loss: 0.1258 - val_accuracy: 0.9604 - val_recall: 0.9583 - val_precision: 0.9643 - val_auc: 0.9970
# Epoch 90/100
# 70/70 [==============================] - 64s 921ms/step - loss: 0.1532 - accuracy: 0.9413 - recall: 0.9390 - precision: 0.9437 - auc: 0.9950 - val_loss: 0.1440 - val_accuracy: 0.9562 - val_recall: 0.9531 - val_precision: 0.9621 - val_auc: 0.9945
# Epoch 91/100
# 70/70 [==============================] - 64s 916ms/step - loss: 0.1589 - accuracy: 0.9379 - recall: 0.9364 - precision: 0.9404 - auc: 0.9949 - val_loss: 0.1433 - val_accuracy: 0.9458 - val_recall: 0.9416 - val_precision: 0.9525 - val_auc: 0.9958
# Epoch 92/100
# 70/70 [==============================] - 64s 916ms/step - loss: 0.1629 - accuracy: 0.9393 - recall: 0.9364 - precision: 0.9423 - auc: 0.9943 - val_loss: 0.1614 - val_accuracy: 0.9385 - val_recall: 0.9353 - val_precision: 0.9403 - val_auc: 0.9941
# Epoch 93/100
# 70/70 [==============================] - 64s 920ms/step - loss: 0.1602 - accuracy: 0.9399 - recall: 0.9379 - precision: 0.9421 - auc: 0.9944 - val_loss: 0.1244 - val_accuracy: 0.9593 - val_recall: 0.9552 - val_precision: 0.9612 - val_auc: 0.9955
# Epoch 94/100
# 70/70 [==============================] - 71s 1s/step - loss: 0.1375 - accuracy: 0.9536 - recall: 0.9507 - precision: 0.9558 - auc: 0.9960 - val_loss: 0.1238 - val_accuracy: 0.9583 - val_recall: 0.9562 - val_precision: 0.9612 - val_auc: 0.9971
# Epoch 95/100
# 70/70 [==============================] - 62s 890ms/step - loss: 0.1384 - accuracy: 0.9466 - recall: 0.9451 - precision: 0.9489 - auc: 0.9957 - val_loss: 0.1338 - val_accuracy: 0.9499 - val_recall: 0.9489 - val_precision: 0.9529 - val_auc: 0.9965
# Epoch 96/100
# 70/70 [==============================] - 63s 898ms/step - loss: 0.1340 - accuracy: 0.9538 - recall: 0.9513 - precision: 0.9556 - auc: 0.9961 - val_loss: 0.1091 - val_accuracy: 0.9614 - val_recall: 0.9593 - val_precision: 0.9644 - val_auc: 0.9971
# Epoch 97/100
# 70/70 [==============================] - 64s 906ms/step - loss: 0.1534 - accuracy: 0.9437 - recall: 0.9422 - precision: 0.9453 - auc: 0.9945 - val_loss: 0.1547 - val_accuracy: 0.9458 - val_recall: 0.9426 - val_precision: 0.9476 - val_auc: 0.9951
# Epoch 98/100
# 70/70 [==============================] - 63s 896ms/step - loss: 0.1438 - accuracy: 0.9449 - recall: 0.9433 - precision: 0.9467 - auc: 0.9958 - val_loss: 0.1339 - val_accuracy: 0.9552 - val_recall: 0.9520 - val_precision: 0.9580 - val_auc: 0.9959
# Epoch 99/100
# 70/70 [==============================] - 65s 933ms/step - loss: 0.1394 - accuracy: 0.9524 - recall: 0.9500 - precision: 0.9534 - auc: 0.9957 - val_loss: 0.1141 - val_accuracy: 0.9625 - val_recall: 0.9614 - val_precision: 0.9665 - val_auc: 0.9964
# Epoch 100/100
# 70/70 [==============================] - 63s 900ms/step - loss: 0.1172 - accuracy: 0.9609 - recall: 0.9585 - precision: 0.9628 - auc: 0.9969 - val_loss: 0.1006 - val_accuracy: 0.9677 - val_recall: 0.9666 - val_precision: 0.9676 - val_auc: 0.9969

# %%
metricsEval = list(model_history.history.keys())
print(metricsEval , '\n')

historyDF = pd.DataFrame(model_history.history)
historyDF.head()
historyDF.to_csv('mycsvfile.csv',index=False)
# Out:
# ['loss', 'accuracy', 'recall', 'precision', 'auc', 'val_loss', 'val_accuracy', 'val_recall', 'val_precision', 'val_auc']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axarr = plt.subplots(1, 5, figsize=(21, 8), sharex=True)

sns.set(style="ticks", font_scale=1)
sns.despine(top=True, right=True, left=False, bottom=False)

# Modify the code to create the lineplots on the same row
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[0]], ax=axarr[0], label="Validation")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[5]], ax=axarr[0], label="Training")
axarr[0].set_ylabel('Loss')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[1]], ax=axarr[1], label="Validation")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[6]], ax=axarr[1], label="Training")
axarr[1].set_ylabel('Accuracy')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[2]], ax=axarr[2], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[7]], ax=axarr[2], label="Validation")
axarr[2].set_ylabel('Precision')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[3]], ax=axarr[3], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[8]], ax=axarr[3], label="Validation")
axarr[3].set_ylabel('Recall')

ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[4]], ax=axarr[4], label="Training")
ax = sns.lineplot(x=historyDF.index, y=model_history.history[metricsEval[9]], ax=axarr[4], label="Validation")
axarr[4].set_ylabel('AUC')

# Modify the titles and labels as needed
axarr[0].set_title('Loss', fontsize=17)
axarr[1].set_title('Accuracy', fontsize=17)
axarr[2].set_title('Precision', fontsize=17)
axarr[3].set_title('Recall', fontsize=17)
axarr[4].set_title('AUC', fontsize=17)

for ax in axarr:
    ax.set_xlabel('Epochs')

plt.suptitle('Training and Validation Performance Plots', fontsize=19, weight='bold')
fig.tight_layout(pad=3.0)
plt.savefig("trainingandval.png", dpi=1080)
plt.show()

# %%
# Assuming you have test_data and test_labels for your test set
test_metrics = model.evaluate(test_data)

test_accuracy = test_metrics[1]
test_precision = test_metrics[3]
test_recall = test_metrics[2]
test_auc = test_metrics[4]

# Calculate F1 score
test_f1_score = 2 * (test_precision * test_recall) / (test_precision + test_recall)

print("Test Accuracy:", test_accuracy)
print("Test Precision:", test_precision)
print("Test Recall:", test_recall)
print("Test AUC:", test_auc)
print("Test F1 Score:", test_f1_score)
# Out:
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0983 - accuracy: 0.9678 - recall: 0.9678 - precision: 0.9678 - auc: 0.9975
# Test Accuracy: 0.9677754640579224
# Test Precision: 0.9677754640579224
# Test Recall: 0.9677754640579224
# Test AUC: 0.997512698173523
# Test F1 Score: 0.9677754640579224

# %%
# !pip install visualkeras
import visualkeras
visualkeras.layered_view(model, legend=True) # without custom font
from PIL import ImageFont

visualkeras.layered_view(model, legend=True, ) # selected font
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.23.5)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 20.4 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18 visualkeras-0.0.2
# <PIL.Image.Image image mode=RGBA size=933x1231>
